# %% [markdown]
# ## Import Stuff

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib.request
import re, warnings, os, requests, time, datetime

from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from scipy import stats

#os.environ['http_proxy'] = "http://204.40.194.129:3128" 
#os.environ['https_proxy'] = "http://204.40.194.129:3128"

# %% [markdown]
# ## Get URL's

# %%
##########
#2020FinalAPPoll
##########

AP20url = 'https://www.foxsports.com/college-basketball/polls?season=2019&poll=1'
AP20page = requests.get(AP20url)
AP20soup = BeautifulSoup(AP20page.text, 'html.parser')

# %%
##########
#2020KenPom
##########

KP20url = 'https://kenpom.com/index.php'

# %%
##########
#2020TeamStats
##########

TS20url1 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points'
TS20page1 = requests.get(TS20url1)
TS20soup1 = BeautifulSoup(TS20page1.text, 'html.parser')

TS20url2 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/41'
TS20page2 = requests.get(TS20url2)
TS20soup2 = BeautifulSoup(TS20page2.text, 'html.parser')

TS20url3 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/81'
TS20page3 = requests.get(TS20url3)
TS20soup3 = BeautifulSoup(TS20page3.text, 'html.parser')

TS20url4 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/121'
TS20page4 = requests.get(TS20url4)
TS20soup4 = BeautifulSoup(TS20page4.text, 'html.parser')

TS20url5 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/161'
TS20page5 = requests.get(TS20url5)
TS20soup5 = BeautifulSoup(TS20page5.text, 'html.parser')

TS20url6 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/201'
TS20page6 = requests.get(TS20url6)
TS20soup6 = BeautifulSoup(TS20page6.text, 'html.parser')

TS20url7 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/241'
TS20page7 = requests.get(TS20url7)
TS20soup7 = BeautifulSoup(TS20page7.text, 'html.parser')

TS20url8 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/281'
TS20page8 = requests.get(TS20url8)
TS20soup8 = BeautifulSoup(TS20page8.text, 'html.parser')

TS20url9 = 'http://www.espn.com/mens-college-basketball/statistics/team/_/stat/scoring/sort/points/count/321'
TS20page9 = requests.get(TS20url9)
TS20soup9 = BeautifulSoup(TS20page9.text, 'html.parser')

# %%
##########
#2020PreSeasonAP
##########

PS20url = 'https://www.foxsports.com/college-basketball/polls?season=2019&poll=1'
PS20page = requests.get(PS20url)
PS20soup = BeautifulSoup(PS20page.text, 'html.parser')

# %%
##########
#2020Standings
##########

STA20league1 = "Atlantic 10"
STA20url1 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=10'
STA20page1 = requests.get(STA20url1)
STA20soup1 = BeautifulSoup(STA20page1.text, 'html.parser')

STA20league2 = "American Athletic"
STA20url2 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=195'
STA20page2 = requests.get(STA20url2)
STA20soup2 = BeautifulSoup(STA20page2.text, 'html.parser')

STA20league3 = "Atlantic Coast"
STA20url3 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=11'
STA20page3 = requests.get(STA20url3)
STA20soup3 = BeautifulSoup(STA20page3.text, 'html.parser')

STA20league4 = "America East"
STA20url4 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=9'
STA20page4 = requests.get(STA20url4)
STA20soup4 = BeautifulSoup(STA20page4.text, 'html.parser')

STA20league5 = "Atlantic Sun"
STA20url5 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=12'
STA20page5 = requests.get(STA20url5)
STA20soup5 = BeautifulSoup(STA20page5.text, 'html.parser')

STA20league6 = "Big Ten"
STA20url6 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=17'
STA20page6 = requests.get(STA20url6)
STA20soup6 = BeautifulSoup(STA20page6.text, 'html.parser')

STA20league7 = "Big 12"
STA20url7 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=13'
STA20page7 = requests.get(STA20url7)
STA20soup7 = BeautifulSoup(STA20page7.text, 'html.parser')

STA20league8 = "Big East"
STA20url8 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=14'
STA20page8 = requests.get(STA20url8)
STA20soup8 = BeautifulSoup(STA20page8.text, 'html.parser')

STA20league9 = "Big Sky"
STA20url9 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=15'
STA20page9 = requests.get(STA20url9)
STA20soup9 = BeautifulSoup(STA20page9.text, 'html.parser')

STA20league10 = "Big South"
STA20url10 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=16'
STA20page10 = requests.get(STA20url10)
STA20soup10 = BeautifulSoup(STA20page10.text, 'html.parser')

STA20league11 = "Big West"
STA20url11 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=18'
STA20page11 = requests.get(STA20url11)
STA20soup11 = BeautifulSoup(STA20page11.text, 'html.parser')

STA20league12 = "Colonial"
STA20url12 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=19'
STA20page12 = requests.get(STA20url12)
STA20soup12 = BeautifulSoup(STA20page12.text, 'html.parser')

STA20league13 = "Conference USA"
STA20url13 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=20'
STA20page13 = requests.get(STA20url13)
STA20soup13 = BeautifulSoup(STA20page13.text, 'html.parser')

STA20league14 = "Horizon"
STA20url14 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=21'
STA20page14 = requests.get(STA20url14)
STA20soup14 = BeautifulSoup(STA20page14.text, 'html.parser')

STA20league15 = "Ivy"
STA20url15 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=23'
STA20page15 = requests.get(STA20url15)
STA20soup15 = BeautifulSoup(STA20page15.text, 'html.parser')

STA20league16 = "Metro Atlantic Athletic"
STA20url16 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=24'
STA20page16 = requests.get(STA20url16)
STA20soup16 = BeautifulSoup(STA20page16.text, 'html.parser')

STA20league17 = "Mid-American"
STA20url17 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=25'
STA20page17 = requests.get(STA20url17)
STA20soup17 = BeautifulSoup(STA20page17.text, 'html.parser')

STA20league18 = "Mid Eastern Athletic"
STA20url18 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=26'
STA20page18 = requests.get(STA20url18)
STA20soup18 = BeautifulSoup(STA20page18.text, 'html.parser')

STA20league19 = "Missouri Valley"
STA20url19 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=27'
STA20page19 = requests.get(STA20url19)
STA20soup19 = BeautifulSoup(STA20page19.text, 'html.parser')

STA20league20 = "Mountain West"
STA20url20 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=28'
STA20page20 = requests.get(STA20url20)
STA20soup20 = BeautifulSoup(STA20page20.text, 'html.parser')

STA20league21 = "Northeast"
STA20url21 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=29'
STA20page21 = requests.get(STA20url21)
STA20soup21 = BeautifulSoup(STA20page21.text, 'html.parser')

STA20league22 = "Ohio Valley"
STA20url22 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=30'
STA20page22 = requests.get(STA20url22)
STA20soup22 = BeautifulSoup(STA20page22.text, 'html.parser')

STA20league23 = "Pacific 12"
STA20url23 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=31'
STA20page23 = requests.get(STA20url23)
STA20soup23 = BeautifulSoup(STA20page23.text, 'html.parser')

STA20league24 = "Patriot League"
STA20url24 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=32'
STA20page24 = requests.get(STA20url24)
STA20soup24 = BeautifulSoup(STA20page24.text, 'html.parser')

STA20league25 = "Southeastern"
STA20url25 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=33'
STA20page25 = requests.get(STA20url25)
STA20soup25 = BeautifulSoup(STA20page25.text, 'html.parser')

STA20league26 = "Southern"
STA20url26 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=34'
STA20page26 = requests.get(STA20url26)
STA20soup26 = BeautifulSoup(STA20page26.text, 'html.parser')

STA20league27 = "Southland"
STA20url27 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=35'
STA20page27 = requests.get(STA20url27)
STA20soup27 = BeautifulSoup(STA20page27.text, 'html.parser')

STA20league28 = "Summit League"
STA20url28 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=37'
STA20page28 = requests.get(STA20url28)
STA20soup28 = BeautifulSoup(STA20page28.text, 'html.parser')

STA20league29 = "Sun Belt"
STA20url29 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=38'
STA20page29 = requests.get(STA20url29)
STA20soup29 = BeautifulSoup(STA20page29.text, 'html.parser')

STA20league30 = "Southwestern Athletic"
STA20url30 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=36'
STA20page30 = requests.get(STA20url30)
STA20soup30 = BeautifulSoup(STA20page30.text, 'html.parser')

STA20league31 = "Western Athletic"
STA20url31 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=40'
STA20page31 = requests.get(STA20url31)
STA20soup31 = BeautifulSoup(STA20page31.text, 'html.parser')

STA20league32 = "West Coast"
STA20url32 = 'https://www.foxsports.com/college-basketball/standings?season=2019&group=39'
STA20page32 = requests.get(STA20url32)
STA20soup32 = BeautifulSoup(STA20page32.text, 'html.parser')

STA20leagues = [STA20league1, STA20league2, STA20league3, STA20league4, STA20league5, STA20league6, STA20league7, STA20league8, STA20league9, STA20league10, STA20league11, STA20league12, STA20league13, STA20league14, STA20league15, STA20league16, STA20league17, STA20league18, STA20league19, STA20league20, STA20league21, STA20league22, STA20league23, STA20league24, STA20league25, STA20league26, STA20league27, STA20league28, STA20league29, STA20league30, STA20league31, STA20league32]
STA20urls = [STA20url1, STA20url2, STA20url3, STA20url4, STA20url5, STA20url6, STA20url7, STA20url8, STA20url9, STA20url10, STA20url11, STA20url12, STA20url13, STA20url14, STA20url15, STA20url16, STA20url17, STA20url18, STA20url19, STA20url20, STA20url21, STA20url22, STA20url23, STA20url24, STA20url25, STA20url26, STA20url27, STA20url28, STA20url29, STA20url30, STA20url31, STA20url32]

# %% [markdown]
# ## KenPom Function

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %% [markdown]
# ## Get Headers

# %%
##########
#2020FinalAPPoll
##########

AP20header = AP20soup.find('div', attrs = {'class':'wisbb_upperHeader'})
AP20columns = [col.get_text() for col in AP20header.find_all('span')]
AP20df = pd.DataFrame(columns=AP20columns)

# %%
##########
#2020TeamStats
##########

TS20header1 = TS20soup1.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns1 = [col.get_text() for col in TS20header1.find_all('td')]
TS20df1 = pd.DataFrame(columns = TS20columns1)

TS20header2 = TS20soup2.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns2 = [col.get_text() for col in TS20header2.find_all('td')]
TS20df2 = pd.DataFrame(columns = TS20columns2)

TS20header3 = TS20soup3.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns3 = [col.get_text() for col in TS20header3.find_all('td')]
TS20df3 = pd.DataFrame(columns = TS20columns3)

TS20header4 = TS20soup4.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns4 = [col.get_text() for col in TS20header4.find_all('td')]
TS20df4 = pd.DataFrame(columns = TS20columns4)

TS20header5 = TS20soup5.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns5 = [col.get_text() for col in TS20header5.find_all('td')]
TS20df5 = pd.DataFrame(columns = TS20columns5)

TS20header6 = TS20soup6.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns6 = [col.get_text() for col in TS20header6.find_all('td')]
TS20df6 = pd.DataFrame(columns = TS20columns6)

TS20header7 = TS20soup7.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns7 = [col.get_text() for col in TS20header7.find_all('td')]
TS20df7 = pd.DataFrame(columns = TS20columns7)

TS20header8 = TS20soup8.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns8 = [col.get_text() for col in TS20header8.find_all('td')]
TS20df8 = pd.DataFrame(columns = TS20columns8)

TS20header9 = TS20soup9.find('tr', attrs = {'class':'colhead', 'align':'right'})
TS20columns9 = [col.get_text() for col in TS20header9.find_all('td')]
TS20df9 = pd.DataFrame(columns = TS20columns9)

# %%
##########
#2020PreSeasonAP
##########

PS20header = PS20soup.find('div', attrs = {'class':'wisbb_upperHeader'})
PS20columns = [col.get_text() for col in PS20header.find_all('span')]
PS20df = pd.DataFrame(columns=PS20columns)

# %%
##########
#2020Standings
##########

STA20str1 = STA20soup1.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header1 = ["Team", "Conf_"+STA20str1[11], "Conf_"+STA20str1[12], "Conf_"+STA20str1[13:16], "Conf_"+STA20str1[16:18], "Conf_"+STA20str1[18:20], STA20str1[20], STA20str1[21], STA20str1[22:25], STA20str1[25:27], STA20str1[27:29], STA20str1[29:33], STA20str1[33:37], STA20str1[37:44], STA20str1[44:50], STA20str1[50:54]]
STA20df1 = pd.DataFrame(columns=STA20header1)

STA20str2 = STA20soup2.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header2 = ["Team", "Conf_"+STA20str2[17], "Conf_"+STA20str2[18], "Conf_"+STA20str2[19:22], "Conf_"+STA20str2[22:24], "Conf_"+STA20str2[24:26], STA20str2[26], STA20str2[27], STA20str2[28:31], STA20str2[31:33], STA20str2[33:35], STA20str2[35:39], STA20str2[39:43], STA20str2[43:50], STA20str2[50:56], STA20str2[56:60]]
STA20df2 = pd.DataFrame(columns=STA20header2)

STA20str3 = STA20soup3.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header3 = ["Team", "Conf_"+STA20str3[14], "Conf_"+STA20str3[15], "Conf_"+STA20str3[16:19], "Conf_"+STA20str3[19:21], "Conf_"+STA20str3[21:23], STA20str3[23], STA20str3[24], STA20str3[25:28], STA20str3[28:30], STA20str3[30:32], STA20str3[32:36], STA20str3[36:40], STA20str3[40:47], STA20str3[47:53], STA20str3[53:57]]
STA20df3 = pd.DataFrame(columns=STA20header3)

STA20str4 = STA20soup4.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header4 = ["Team", "Conf_"+STA20str4[12], "Conf_"+STA20str4[13], "Conf_"+STA20str4[14:17], "Conf_"+STA20str4[17:19], "Conf_"+STA20str4[19:21], STA20str4[21], STA20str4[22], STA20str4[23:26], STA20str4[26:28], STA20str4[28:30], STA20str4[30:34], STA20str4[34:38], STA20str4[38:45], STA20str4[45:51], STA20str4[51:55]]
STA20df4 = pd.DataFrame(columns=STA20header4)

STA20str5 = STA20soup5.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header5 = ["Team", "Conf_"+STA20str5[12], "Conf_"+STA20str5[13], "Conf_"+STA20str5[14:17], "Conf_"+STA20str5[17:19], "Conf_"+STA20str5[19:21], STA20str5[21], STA20str5[22], STA20str5[23:26], STA20str5[26:28], STA20str5[28:30], STA20str5[30:34], STA20str5[34:38], STA20str5[38:45], STA20str5[45:51], STA20str5[51:55]]
STA20df5 = pd.DataFrame(columns=STA20header5)

STA20str6 = STA20soup6.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header6 = ["Team", "Conf_"+STA20str6[7], "Conf_"+STA20str6[8], "Conf_"+STA20str6[9:12], "Conf_"+STA20str6[12:14], "Conf_"+STA20str6[14:16], STA20str6[16], STA20str6[17], STA20str6[18:21], STA20str6[21:23], STA20str6[23:25], STA20str6[25:29], STA20str6[29:33], STA20str6[33:40], STA20str6[40:46], STA20str6[46:50]]
STA20df6 = pd.DataFrame(columns=STA20header6)

STA20str7 = STA20soup7.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header7 = ["Team", "Conf_"+STA20str7[6], "Conf_"+STA20str7[7], "Conf_"+STA20str7[8:11], "Conf_"+STA20str7[11:13], "Conf_"+STA20str7[13:15], STA20str7[15], STA20str7[16], STA20str7[17:20], STA20str7[20:22], STA20str7[22:24], STA20str7[24:28], STA20str7[28:32], STA20str7[32:39], STA20str7[39:45], STA20str7[45:49]]
STA20df7 = pd.DataFrame(columns=STA20header7)

STA20str8 = STA20soup8.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header8 = ["Team", "Conf_"+STA20str8[8], "Conf_"+STA20str8[9], "Conf_"+STA20str8[10:13], "Conf_"+STA20str8[13:15], "Conf_"+STA20str8[15:17], STA20str8[17], STA20str8[18], STA20str8[19:22], STA20str8[22:24], STA20str8[24:26], STA20str8[26:30], STA20str8[30:34], STA20str8[34:41], STA20str8[41:47], STA20str8[47:51]]
STA20df8 = pd.DataFrame(columns=STA20header8)

STA20str9 = STA20soup9.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header9 = ["Team", "Conf_"+STA20str9[7], "Conf_"+STA20str9[8], "Conf_"+STA20str9[9:12], "Conf_"+STA20str9[12:14], "Conf_"+STA20str9[14:16], STA20str9[16], STA20str9[17], STA20str9[18:21], STA20str9[21:23], STA20str9[23:25], STA20str9[25:29], STA20str9[29:33], STA20str9[33:40], STA20str9[40:46], STA20str9[46:50]]
STA20df9 = pd.DataFrame(columns=STA20header9)

STA20str10 = STA20soup10.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header10 = ["Team", "Conf_"+STA20str10[9], "Conf_"+STA20str10[10], "Conf_"+STA20str10[11:14], "Conf_"+STA20str10[14:16], "Conf_"+STA20str10[16:18], STA20str10[18], STA20str10[19], STA20str10[20:23], STA20str10[23:25], STA20str10[25:27], STA20str10[27:31], STA20str10[31:35], STA20str10[35:42], STA20str10[42:48], STA20str10[48:52]]
STA20df10 = pd.DataFrame(columns=STA20header10)

STA20str11 = STA20soup11.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header11 = ["Team", "Conf_"+STA20str11[8], "Conf_"+STA20str11[9], "Conf_"+STA20str11[10:13], "Conf_"+STA20str11[13:15], "Conf_"+STA20str11[15:17], STA20str11[17], STA20str11[18], STA20str11[19:22], STA20str11[22:24], STA20str11[24:26], STA20str11[26:30], STA20str11[30:34], STA20str11[34:41], STA20str11[41:47], STA20str11[47:51]]
STA20df11 = pd.DataFrame(columns=STA20header11)

STA20str12 = STA20soup12.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header12 = ["Team", "Conf_"+STA20str12[17], "Conf_"+STA20str12[18], "Conf_"+STA20str12[19:22], "Conf_"+STA20str12[22:24], "Conf_"+STA20str12[24:26], STA20str12[26], STA20str12[27], STA20str12[28:31], STA20str12[31:33], STA20str12[33:35], STA20str12[35:39], STA20str12[39:43], STA20str12[43:50], STA20str12[50:56], STA20str12[56:60]]
STA20df12 = pd.DataFrame(columns=STA20header12)

STA20str13 = STA20soup13.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header13 = ["Team", "Conf_"+STA20str13[14], "Conf_"+STA20str13[15], "Conf_"+STA20str13[16:19], "Conf_"+STA20str13[19:21], "Conf_"+STA20str13[21:23], STA20str13[23], STA20str13[24], STA20str13[25:28], STA20str13[28:30], STA20str13[30:32], STA20str13[32:36], STA20str13[36:40], STA20str13[40:47], STA20str13[47:53], STA20str13[53:57]]
STA20df13 = pd.DataFrame(columns=STA20header13)

STA20str14 = STA20soup14.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header14 = ["Team", "Conf_"+STA20str14[7], "Conf_"+STA20str14[8], "Conf_"+STA20str14[9:12], "Conf_"+STA20str14[12:14], "Conf_"+STA20str14[14:16], STA20str14[16], STA20str14[17], STA20str14[18:21], STA20str14[21:23], STA20str14[23:25], STA20str14[25:29], STA20str14[29:33], STA20str14[33:40], STA20str14[40:46], STA20str14[46:50]]
STA20df14 = pd.DataFrame(columns=STA20header14)

STA20str15 = STA20soup15.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header15 = ["Team", "Conf_"+STA20str15[10], "Conf_"+STA20str15[11], "Conf_"+STA20str15[12:15], "Conf_"+STA20str15[15:17], "Conf_"+STA20str15[17:19], STA20str15[19], STA20str15[20], STA20str15[21:24], STA20str15[24:26], STA20str15[26:28], STA20str15[28:32], STA20str15[32:36], STA20str15[36:43], STA20str15[43:49], STA20str15[49:53]]
STA20df15 = pd.DataFrame(columns=STA20header15)

STA20str16 = STA20soup16.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header16 = ["Team", "Conf_"+STA20str16[23], "Conf_"+STA20str16[24], "Conf_"+STA20str16[25:28], "Conf_"+STA20str16[28:30], "Conf_"+STA20str16[30:32], STA20str16[32], STA20str16[33], STA20str16[34:37], STA20str16[37:39], STA20str16[39:41], STA20str16[41:45], STA20str16[45:49], STA20str16[49:56], STA20str16[56:62], STA20str16[62:66]]
STA20df16 = pd.DataFrame(columns=STA20header16)

STA20str17 = STA20soup17.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header17 = ["Team", "Conf_"+STA20str17[12], "Conf_"+STA20str17[13], "Conf_"+STA20str17[14:17], "Conf_"+STA20str17[17:19], "Conf_"+STA20str17[19:21], STA20str17[21], STA20str17[22], STA20str17[23:26], STA20str17[26:28], STA20str17[28:30], STA20str17[30:34], STA20str17[34:38], STA20str17[38:45], STA20str17[45:51], STA20str17[51:55]]
STA20df17 = pd.DataFrame(columns=STA20header17)

STA20str18 = STA20soup18.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header18 = ["Team", "Conf_"+STA20str18[20], "Conf_"+STA20str18[21], "Conf_"+STA20str18[22:25], "Conf_"+STA20str18[25:27], "Conf_"+STA20str18[27:29], STA20str18[29], STA20str18[30], STA20str18[31:34], STA20str18[34:36], STA20str18[36:38], STA20str18[38:42], STA20str18[42:46], STA20str18[46:53], STA20str18[53:59], STA20str18[59:63]]
STA20df18 = pd.DataFrame(columns=STA20header18)

STA20str19 = STA20soup19.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header19 = ["Team", "Conf_"+STA20str19[15], "Conf_"+STA20str19[16], "Conf_"+STA20str19[17:20], "Conf_"+STA20str19[20:22], "Conf_"+STA20str19[22:24], STA20str19[24], STA20str19[25], STA20str19[26:29], STA20str19[29:31], STA20str19[31:33], STA20str19[33:37], STA20str19[37:41], STA20str19[41:48], STA20str19[48:54], STA20str19[54:58]]
STA20df19 = pd.DataFrame(columns=STA20header19)

STA20str20 = STA20soup20.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header20 = ["Team", "Conf_"+STA20str20[13], "Conf_"+STA20str20[14], "Conf_"+STA20str20[15:18], "Conf_"+STA20str20[18:20], "Conf_"+STA20str20[20:22], STA20str20[22], STA20str20[23], STA20str20[24:27], STA20str20[27:29], STA20str20[29:31], STA20str20[31:35], STA20str20[35:39], STA20str20[39:46], STA20str20[46:52], STA20str20[52:56]]
STA20df20 = pd.DataFrame(columns=STA20header20)

STA20str21 = STA20soup21.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header21 = ["Team", "Conf_"+STA20str21[9], "Conf_"+STA20str21[10], "Conf_"+STA20str21[11:14], "Conf_"+STA20str21[14:16], "Conf_"+STA20str21[16:18], STA20str21[18], STA20str21[19], STA20str21[20:23], STA20str21[23:25], STA20str21[25:27], STA20str21[27:31], STA20str21[31:35], STA20str21[35:42], STA20str21[42:48], STA20str21[48:52]]
STA20df21 = pd.DataFrame(columns=STA20header21)

STA20str22 = STA20soup22.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header22 = ["Team", "Conf_"+STA20str22[11], "Conf_"+STA20str22[12], "Conf_"+STA20str22[13:16], "Conf_"+STA20str22[16:18], "Conf_"+STA20str22[18:20], STA20str22[20], STA20str22[21], STA20str22[22:25], STA20str22[25:27], STA20str22[27:29], STA20str22[29:33], STA20str22[33:37], STA20str22[37:44], STA20str22[44:50], STA20str22[50:54]]
STA20df22 = pd.DataFrame(columns=STA20header22)

STA20str23 = STA20soup23.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header23 = ["Team", "Conf_"+STA20str23[6], "Conf_"+STA20str23[7], "Conf_"+STA20str23[8:11], "Conf_"+STA20str23[11:13], "Conf_"+STA20str23[13:15], STA20str23[15], STA20str23[16], STA20str23[17:20], STA20str23[20:22], STA20str23[22:24], STA20str23[24:28], STA20str23[28:32], STA20str23[32:39], STA20str23[39:45], STA20str23[45:49]]
STA20df23 = pd.DataFrame(columns=STA20header23)

STA20str24 = STA20soup24.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header24 = ["Team", "Conf_"+STA20str24[14], "Conf_"+STA20str24[15], "Conf_"+STA20str24[16:19], "Conf_"+STA20str24[19:21], "Conf_"+STA20str24[21:23], STA20str24[23], STA20str24[24], STA20str24[25:28], STA20str24[28:30], STA20str24[30:32], STA20str24[32:36], STA20str24[36:40], STA20str24[40:47], STA20str24[47:53], STA20str24[53:57]]
STA20df24 = pd.DataFrame(columns=STA20header24)

STA20str25 = STA20soup25.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header25 = ["Team", "Conf_"+STA20str25[12], "Conf_"+STA20str25[13], "Conf_"+STA20str25[14:17], "Conf_"+STA20str25[17:19], "Conf_"+STA20str25[19:21], STA20str25[21], STA20str25[22], STA20str25[23:26], STA20str25[26:28], STA20str25[28:30], STA20str25[30:34], STA20str25[34:38], STA20str25[38:45], STA20str25[45:51], STA20str25[51:55]]
STA20df25 = pd.DataFrame(columns=STA20header25)

STA20str26 = STA20soup26.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header26 = ["Team", "Conf_"+STA20str26[8], "Conf_"+STA20str26[9], "Conf_"+STA20str26[10:13], "Conf_"+STA20str26[13:15], "Conf_"+STA20str26[15:17], STA20str26[17], STA20str26[18], STA20str26[19:22], STA20str26[22:24], STA20str26[24:26], STA20str26[26:30], STA20str26[30:34], STA20str26[34:41], STA20str26[41:47], STA20str26[47:51]]
STA20df26 = pd.DataFrame(columns=STA20header26)

STA20str27 = STA20soup27.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header27 = ["Team", "Conf_"+STA20str27[9], "Conf_"+STA20str27[10], "Conf_"+STA20str27[11:14], "Conf_"+STA20str27[14:16], "Conf_"+STA20str27[16:18], STA20str27[18], STA20str27[19], STA20str27[20:23], STA20str27[23:25], STA20str27[25:27], STA20str27[27:31], STA20str27[31:35], STA20str27[35:42], STA20str27[42:48], STA20str27[48:52]]
STA20df27 = pd.DataFrame(columns=STA20header27)

STA20str28 = STA20soup28.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header28 = ["Team", "Conf_"+STA20str28[13], "Conf_"+STA20str28[14], "Conf_"+STA20str28[15:18], "Conf_"+STA20str28[18:20], "Conf_"+STA20str28[20:22], STA20str28[22], STA20str28[23], STA20str28[24:27], STA20str28[27:29], STA20str28[29:31], STA20str28[31:35], STA20str28[35:39], STA20str28[39:46], STA20str28[46:52], STA20str28[52:56]]
STA20df28 = pd.DataFrame(columns=STA20header28)

STA20str29 = STA20soup2.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header29 = ["Team", "Conf_"+STA20str29[17], "Conf_"+STA20str29[18], "Conf_"+STA20str29[19:22], "Conf_"+STA20str29[22:24], "Conf_"+STA20str29[24:26], STA20str29[26], STA20str29[27], STA20str29[28:31], STA20str29[31:33], STA20str29[33:35], STA20str29[35:39], STA20str29[39:43], STA20str29[43:50], STA20str29[50:56], STA20str29[56:60]]
STA20df29 = pd.DataFrame(columns=STA20header29)

STA20str30 = STA20soup30.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header30 = ["Team", "Conf_"+STA20str30[21], "Conf_"+STA20str30[22], "Conf_"+STA20str30[23:26], "Conf_"+STA20str30[26:28], "Conf_"+STA20str30[28:30], STA20str30[30], STA20str30[31], STA20str30[32:35], STA20str30[35:37], STA20str30[37:39], STA20str30[39:43], STA20str30[43:47], STA20str30[47:54], STA20str30[54:60], STA20str30[60:64]]
STA20df30 = pd.DataFrame(columns=STA20header30)

STA20str31 = STA20soup31.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header31 = ["Team", "Conf_"+STA20str31[16], "Conf_"+STA20str31[17], "Conf_"+STA20str31[18:21], "Conf_"+STA20str31[21:23], "Conf_"+STA20str31[23:25], STA20str31[25], STA20str31[26], STA20str31[27:30], STA20str31[30:32], STA20str31[32:34], STA20str31[34:38], STA20str31[38:42], STA20str31[42:49], STA20str31[49:55], STA20str31[55:59]]
STA20df31 = pd.DataFrame(columns=STA20header31)

STA20str32 = STA20soup32.select_one('thead > tr:nth-of-type(2)').get_text(strip=True)
STA20header32 = ["Team", "Conf_"+STA20str32[10], "Conf_"+STA20str32[11], "Conf_"+STA20str32[12:15], "Conf_"+STA20str32[15:17], "Conf_"+STA20str32[17:19], STA20str32[19], STA20str32[20], STA20str32[21:24], STA20str32[24:26], STA20str32[26:28], STA20str32[28:32], STA20str32[32:36], STA20str32[36:43], STA20str32[43:49], STA20str32[49:53]]
STA20df32 = pd.DataFrame(columns=STA20header32)

# %% [markdown]
# ## Get Data

# %%
##########
#2020FinalAPPoll
##########

AP20teams = AP20soup.find_all('div', attrs = {'class':re.compile('wisbb_pollTeamUpper')})
for team in AP20teams:
    AP20ranks = [rank.get_text() for rank in team.find_all('div')]
    AP20temp_df = pd.DataFrame(AP20ranks).transpose()
    AP20temp_df.columns = AP20columns
    AP20df = pd.concat([AP20df,AP20temp_df], ignore_index=True)
AP20df = AP20df[0:25]

AP20df['Rnk'] = AP20df['Rnk'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n'))
AP20df['Team'] = AP20df['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n1234567890()'))
AP20df['Rec'] = AP20df['Rec'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n'))
AP20df[['W','L']] = AP20df['Rec'].str.split('-',expand=True)
AP20df = AP20df.drop('Rec', axis = 1)

# %%
##########
#2020KenPom
##########

lvars20 = 21
dictary20 = {}
raw_html20 = simple_get(KP20url)
soup20 = BeautifulSoup(raw_html20, 'html5lib')
dta20 = [s.text for s in soup20.select('td')]
ldta20 = len(dta20)
dictary20[lvars20] = pd.DataFrame(np.array(dta20).reshape(int((ldta20/lvars20)),lvars20))
KP20df = dictary20[lvars20]

KP20df.columns = ['Rank', 'Team', 'Conference', 'W-L', 'Adjusted Efficiency Margin', 'Adjusted Offensive Efficiency', 'AOE Rk', 'Adjusted Defensive Efficiency', 'ADE Rk', 'Adjusted Tempo', 'AT Rk', 'Luck', 'L Rk', 'Strength of Schedule', 'SOS Rk', 'Average Opponents Offensive Efficiency', 'AOOE Rk', 'Average Opponents Defensive Efficiency', 'AODE Rk', 'Non-Conference Strength of Schedule', 'NCSOS Rk']
KP20df[['W','L']] = KP20df['W-L'].str.split('-',expand=True)
KP20df = KP20df.drop('W-L', axis = 1)
KP20df['Team'] = KP20df['Team'].map(lambda x: x.rstrip(" 123456789"))

# %%
##########
#2020TeamStats
##########

TS20teams1 = TS20soup1.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams1:
    TS20ranks1 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df1 = pd.DataFrame(TS20ranks1).transpose()
    TS20temp_df1.columns = TS20columns1
    TS20df1 = pd.concat([TS20df1,TS20temp_df1], ignore_index=True)

TS20teams2 = TS20soup2.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams2:
    TS20ranks2 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df2 = pd.DataFrame(TS20ranks2).transpose()
    TS20temp_df2.columns = TS20columns2
    TS20df2 = pd.concat([TS20df2,TS20temp_df2], ignore_index=True)
    
TS20teams3 = TS20soup3.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams3:
    TS20ranks3 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df3 = pd.DataFrame(TS20ranks3).transpose()
    TS20temp_df3.columns = TS20columns3
    TS20df3 = pd.concat([TS20df3,TS20temp_df3], ignore_index=True)
    
TS20teams4 = TS20soup4.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams4:
    TS20ranks4 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df4 = pd.DataFrame(TS20ranks4).transpose()
    TS20temp_df4.columns = TS20columns4
    TS20df4 = pd.concat([TS20df4,TS20temp_df4], ignore_index=True)

TS20teams5 = TS20soup5.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams5:
    TS20ranks5 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df5 = pd.DataFrame(TS20ranks5).transpose()
    TS20temp_df5.columns = TS20columns5
    TS20df5 = pd.concat([TS20df5,TS20temp_df5], ignore_index=True)
    
TS20teams6 = TS20soup6.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams6:
    TS20ranks6 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df6 = pd.DataFrame(TS20ranks6).transpose()
    TS20temp_df6.columns = TS20columns6
    TS20df6 = pd.concat([TS20df6,TS20temp_df6], ignore_index=True)
    
TS20teams7 = TS20soup7.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams7:
    TS20ranks7 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df7 = pd.DataFrame(TS20ranks7).transpose()
    TS20temp_df7.columns = TS20columns7
    TS20df7 = pd.concat([TS20df7,TS20temp_df7], ignore_index=True)
    
TS20teams8 = TS20soup8.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams8:
    TS20ranks8 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df8 = pd.DataFrame(TS20ranks8).transpose()
    TS20temp_df8.columns = TS20columns8
    TS20df8 = pd.concat([TS20df8,TS20temp_df8], ignore_index=True)
    
TS20teams9 = TS20soup9.find_all('tr', attrs={'class':re.compile('row team-41-')})
for team in TS20teams9:
    TS20ranks9 = [rank.get_text() for rank in team.find_all('td')]
    TS20temp_df9 = pd.DataFrame(TS20ranks9).transpose()
    TS20temp_df9.columns = TS20columns9
    TS20df9 = pd.concat([TS20df9,TS20temp_df9], ignore_index=True)
    
TS20df = pd.concat([TS20df1,TS20df2,TS20df3,TS20df4,TS20df5,TS20df6,TS20df7,TS20df8,TS20df9], ignore_index = True)
TS20df = TS20df.drop('RK', axis = 1)
TS20df[['FGM','FGA']] = TS20df['FGM-FGA'].str.split('-', expand=True)
TS20df[['3PM','3PA']] = TS20df['3PM-3PA'].str.split('-', expand=True)
TS20df[['FTM','FTA']] = TS20df['FTM-FTA'].str.split('-', expand=True)
TS20df = TS20df.drop('FGM-FGA', axis = 1).drop('3PM-3PA', axis = 1).drop('FTM-FTA', axis = 1)

# %%
##########
#2020PreSeasonAP
##########

PS20teams = PS20soup.find_all('div', attrs = {'class':re.compile('wisbb_pollTeamUpper')})
for team in PS20teams:
    PS20ranks = [rank.get_text() for rank in team.find_all('div')]
    PS20temp_df = pd.DataFrame(PS20ranks).transpose()
    PS20temp_df.columns = PS20columns
    PS20df = pd.concat([PS20df,PS20temp_df], ignore_index=True)
PS20df = PS20df[0:25]

PS20df['Rnk'] = PS20df['Rnk'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n'))
PS20df['Team'] = PS20df['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n1234567890()'))
PS20df['Rec'] = PS20df['Rec'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n'))
PS20df = PS20df.drop('Rec', axis = 1)

# %%
##########
#2020Standings
##########

STA20teams1 = STA20soup1.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams1:
    STA20ranks1 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df1 = pd.DataFrame(STA20ranks1).transpose()
    STA20temp_df1.columns = STA20header1
    STA20df1 = pd.concat([STA20df1,STA20temp_df1], ignore_index=True)

STA20teams2 = STA20soup2.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams2:
    STA20ranks2 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df2 = pd.DataFrame(STA20ranks2).transpose()
    STA20temp_df2.columns = STA20header2
    STA20df2 = pd.concat([STA20df2,STA20temp_df2], ignore_index=True)

STA20teams3 = STA20soup3.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams3:
    STA20ranks3 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df3 = pd.DataFrame(STA20ranks3).transpose()
    STA20temp_df3.columns = STA20header3
    STA20df3 = pd.concat([STA20df3,STA20temp_df3], ignore_index=True)

STA20teams4 = STA20soup4.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams4:
    STA20ranks4 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df4 = pd.DataFrame(STA20ranks4).transpose()
    STA20temp_df4.columns = STA20header4
    STA20df4 = pd.concat([STA20df4,STA20temp_df4], ignore_index=True)

STA20teams5 = STA20soup5.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams5:
    STA20ranks5 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df5 = pd.DataFrame(STA20ranks5).transpose()
    STA20temp_df5.columns = STA20header5
    STA20df5 = pd.concat([STA20df5,STA20temp_df5], ignore_index=True)

STA20teams6 = STA20soup6.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams6:
    STA20ranks6 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df6 = pd.DataFrame(STA20ranks6).transpose()
    STA20temp_df6.columns = STA20header6
    STA20df6 = pd.concat([STA20df6,STA20temp_df6], ignore_index=True)

STA20teams7 = STA20soup7.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams7:
    STA20ranks7 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df7 = pd.DataFrame(STA20ranks7).transpose()
    STA20temp_df7.columns = STA20header7
    STA20df7 = pd.concat([STA20df7,STA20temp_df7], ignore_index=True)

STA20teams8 = STA20soup8.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams8:
    STA20ranks8 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df8 = pd.DataFrame(STA20ranks8).transpose()
    STA20temp_df8.columns = STA20header8
    STA20df8 = pd.concat([STA20df8,STA20temp_df8], ignore_index=True)

STA20teams9 = STA20soup9.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams9:
    STA20ranks9 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df9 = pd.DataFrame(STA20ranks9).transpose()
    STA20temp_df9.columns = STA20header9
    STA20df9 = pd.concat([STA20df9,STA20temp_df9], ignore_index=True)

STA20teams10 = STA20soup10.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams10:
    STA20ranks10 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df10 = pd.DataFrame(STA20ranks10).transpose()
    STA20temp_df10.columns = STA20header10
    STA20df10 = pd.concat([STA20df10,STA20temp_df10], ignore_index=True)

STA20teams11 = STA20soup11.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams11:
    STA20ranks11 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df11 = pd.DataFrame(STA20ranks11).transpose()
    STA20temp_df11.columns = STA20header11
    STA20df11 = pd.concat([STA20df11,STA20temp_df11], ignore_index=True)

STA20teams12 = STA20soup12.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams12:
    STA20ranks12 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df12 = pd.DataFrame(STA20ranks12).transpose()
    STA20temp_df12.columns = STA20header12
    STA20df12 = pd.concat([STA20df12,STA20temp_df12], ignore_index=True)

STA20teams13 = STA20soup13.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams13:
    STA20ranks13 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df13 = pd.DataFrame(STA20ranks13).transpose()
    STA20temp_df13.columns = STA20header13
    STA20df13 = pd.concat([STA20df13,STA20temp_df13], ignore_index=True)

STA20teams14 = STA20soup14.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams14:
    STA20ranks14 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df14 = pd.DataFrame(STA20ranks14).transpose()
    STA20temp_df14.columns = STA20header14
    STA20df14 = pd.concat([STA20df14,STA20temp_df14], ignore_index=True)

STA20teams15 = STA20soup15.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams15:
    STA20ranks15 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df15 = pd.DataFrame(STA20ranks15).transpose()
    STA20temp_df15.columns = STA20header15
    STA20df15 = pd.concat([STA20df15,STA20temp_df15], ignore_index=True)

STA20teams16 = STA20soup16.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams16:
    STA20ranks16 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df16 = pd.DataFrame(STA20ranks16).transpose()
    STA20temp_df16.columns = STA20header16
    STA20df16 = pd.concat([STA20df16,STA20temp_df16], ignore_index=True)

STA20teams17 = STA20soup17.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams17:
    STA20ranks17 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df17 = pd.DataFrame(STA20ranks17).transpose()
    STA20temp_df17.columns = STA20header17
    STA20df17 = pd.concat([STA20df17,STA20temp_df17], ignore_index=True)

STA20teams18 = STA20soup18.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams18:
    STA20ranks18 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df18 = pd.DataFrame(STA20ranks18).transpose()
    STA20temp_df18.columns = STA20header18
    STA20df18 = pd.concat([STA20df18,STA20temp_df18], ignore_index=True)

STA20teams19 = STA20soup19.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams19:
    STA20ranks19 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df19 = pd.DataFrame(STA20ranks19).transpose()
    STA20temp_df19.columns = STA20header19
    STA20df19 = pd.concat([STA20df19,STA20temp_df19], ignore_index=True)

STA20teams20 = STA20soup20.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams20:
    STA20ranks20 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df20 = pd.DataFrame(STA20ranks20).transpose()
    STA20temp_df20.columns = STA20header20
    STA20df20 = pd.concat([STA20df20,STA20temp_df20], ignore_index=True)

STA20teams21 = STA20soup21.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams21:
    STA20ranks21 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df21 = pd.DataFrame(STA20ranks21).transpose()
    STA20temp_df21.columns = STA20header21
    STA20df21 = pd.concat([STA20df21,STA20temp_df21], ignore_index=True)

STA20teams22 = STA20soup22.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams22:
    STA20ranks22 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df22 = pd.DataFrame(STA20ranks22).transpose()
    STA20temp_df22.columns = STA20header22
    STA20df22 = pd.concat([STA20df22,STA20temp_df22], ignore_index=True)

STA20teams23 = STA20soup23.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams23:
    STA20ranks23 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df23 = pd.DataFrame(STA20ranks23).transpose()
    STA20temp_df23.columns = STA20header23
    STA20df23 = pd.concat([STA20df23,STA20temp_df23], ignore_index=True)

STA20teams24 = STA20soup24.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams24:
    STA20ranks24 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df24 = pd.DataFrame(STA20ranks24).transpose()
    STA20temp_df24.columns = STA20header24
    STA20df24 = pd.concat([STA20df24,STA20temp_df24], ignore_index=True)

STA20teams25 = STA20soup25.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams25:
    STA20ranks25 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df25 = pd.DataFrame(STA20ranks25).transpose()
    STA20temp_df25.columns = STA20header25
    STA20df25 = pd.concat([STA20df25,STA20temp_df25], ignore_index=True)

STA20teams26 = STA20soup26.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams26:
    STA20ranks26 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df26 = pd.DataFrame(STA20ranks26).transpose()
    STA20temp_df26.columns = STA20header26
    STA20df26 = pd.concat([STA20df26,STA20temp_df26], ignore_index=True)

STA20teams27 = STA20soup27.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams27:
    STA20ranks27 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df27 = pd.DataFrame(STA20ranks27).transpose()
    STA20temp_df27.columns = STA20header27
    STA20df27 = pd.concat([STA20df27,STA20temp_df27], ignore_index=True)

STA20teams28 = STA20soup28.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams28:
    STA20ranks28 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df28 = pd.DataFrame(STA20ranks28).transpose()
    STA20temp_df28.columns = STA20header28
    STA20df28 = pd.concat([STA20df28,STA20temp_df28], ignore_index=True)

STA20teams29 = STA20soup29.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams29:
    STA20ranks29 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df29 = pd.DataFrame(STA20ranks29).transpose()
    STA20temp_df29.columns = STA20header29
    STA20df29 = pd.concat([STA20df29,STA20temp_df29], ignore_index=True)

STA20teams30 = STA20soup30.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams30:
    STA20ranks30 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df30 = pd.DataFrame(STA20ranks30).transpose()
    STA20temp_df30.columns = STA20header30
    STA20df30 = pd.concat([STA20df30,STA20temp_df30], ignore_index=True)

STA20teams31 = STA20soup31.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams31:
    STA20ranks31 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df31 = pd.DataFrame(STA20ranks31).transpose()
    STA20temp_df31.columns = STA20header31
    STA20df31 = pd.concat([STA20df31,STA20temp_df31], ignore_index=True)

STA20teams32 = STA20soup32.find_all('tr', attrs = {'class':re.compile('wisbb_fvStand'), 'data-favorites-config': re.compile('[{"entityType":1,"uri":"basketball/cbk/teams/"}]')})
for team in STA20teams32:
    STA20ranks32 = [rank.get_text() for rank in team.find_all('td')]
    STA20temp_df32 = pd.DataFrame(STA20ranks32).transpose()
    STA20temp_df32.columns = STA20header32
    STA20df32 = pd.concat([STA20df32,STA20temp_df32], ignore_index=True)
    

STA20df1['Team'] = STA20df1['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEFGHIJKLMNOPQRSTWXYZ'))
STA20df1['Conf_W'] = pd.to_numeric(STA20df1["Conf_W"])
STA20df1['Conf_L'] = pd.to_numeric(STA20df1["Conf_L"])
STA20df1['W'] = pd.to_numeric(STA20df1['W'])
STA20df1['L'] = pd.to_numeric(STA20df1['L'])
STA20df1['Conf_PF'] = pd.to_numeric(STA20df1['Conf_PF'])
STA20df1['Conf_PA'] = pd.to_numeric(STA20df1['Conf_PA'])
STA20df1['PF'] = pd.to_numeric(STA20df1['PF'])
STA20df1['PA'] = pd.to_numeric(STA20df1['PA'])
STA20df1["Conf_PPG"] = STA20df1['Conf_PF']/(STA20df1['Conf_W'] + STA20df1['Conf_L'])
STA20df1["Conf_PAPG"] = STA20df1['Conf_PA']/(STA20df1['Conf_W'] + STA20df1['Conf_L'])
STA20df1['PPG'] = STA20df1['PF']/(STA20df1['W'] + STA20df1['L'])
STA20df1['PAPG'] = STA20df1['PA']/(STA20df1['W'] + STA20df1['L'])
STA20df1[['Home_W','Home_L']] = STA20df1['Home'].str.split('-',expand=True)
STA20df1[['Away_W','Away_L']] = STA20df1['Away'].str.split('-',expand=True)
STA20df1[['Neutral_W', 'Neutral_L']] = STA20df1['Neutral'].str.split('-',expand=True)
STA20df1[['Top25_W', 'Top25_L']] = STA20df1['Top 25'].str.split('-',expand=True)
STA20df1 = STA20df1.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df2['Team'] = STA20df2['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEGHIJKLNOPQRTVWXYZ'))
STA20df2['Conf_W'] = pd.to_numeric(STA20df2["Conf_W"])
STA20df2['Conf_L'] = pd.to_numeric(STA20df2["Conf_L"])
STA20df2['W'] = pd.to_numeric(STA20df2['W'])
STA20df2['L'] = pd.to_numeric(STA20df2['L'])
STA20df2['Conf_PF'] = pd.to_numeric(STA20df2['Conf_PF'])
STA20df2['Conf_PA'] = pd.to_numeric(STA20df2['Conf_PA'])
STA20df2['PF'] = pd.to_numeric(STA20df2['PF'])
STA20df2['PA'] = pd.to_numeric(STA20df2['PA'])
STA20df2["Conf_PPG"] = STA20df2['Conf_PF']/(STA20df2['Conf_W'] + STA20df2['Conf_L'])
STA20df2["Conf_PAPG"] = STA20df2['Conf_PA']/(STA20df2['Conf_W'] + STA20df2['Conf_L'])
STA20df2['PPG'] = STA20df2['PF']/(STA20df2['W'] + STA20df2['L'])
STA20df2['PAPG'] = STA20df2['PA']/(STA20df2['W'] + STA20df2['L'])
STA20df2[['Home_W','Home_L']] = STA20df2['Home'].str.split('-',expand=True)
STA20df2[['Away_W','Away_L']] = STA20df2['Away'].str.split('-',expand=True)
STA20df2[['Neutral_W', 'Neutral_L']] = STA20df2['Neutral'].str.split('-',expand=True)
STA20df2[['Top25_W', 'Top25_L']] = STA20df2['Top 25'].str.split('-',expand=True)
STA20df2 = STA20df2.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df3['Team'] = STA20df3['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df3['Conf_W'] = pd.to_numeric(STA20df3["Conf_W"])
STA20df3['Conf_L'] = pd.to_numeric(STA20df3["Conf_L"])
STA20df3['W'] = pd.to_numeric(STA20df3['W'])
STA20df3['L'] = pd.to_numeric(STA20df3['L'])
STA20df3['Conf_PF'] = pd.to_numeric(STA20df3['Conf_PF'])
STA20df3['Conf_PA'] = pd.to_numeric(STA20df3['Conf_PA'])
STA20df3['PF'] = pd.to_numeric(STA20df3['PF'])
STA20df3['PA'] = pd.to_numeric(STA20df3['PA'])
STA20df3["Conf_PPG"] = STA20df3['Conf_PF']/(STA20df3['Conf_W'] + STA20df3['Conf_L'])
STA20df3["Conf_PAPG"] = STA20df3['Conf_PA']/(STA20df3['Conf_W'] + STA20df3['Conf_L'])
STA20df3['PPG'] = STA20df3['PF']/(STA20df3['W'] + STA20df3['L'])
STA20df3['PAPG'] = STA20df3['PA']/(STA20df3['W'] + STA20df3['L'])
STA20df3[['Home_W','Home_L']] = STA20df3['Home'].str.split('-',expand=True)
STA20df3[['Away_W','Away_L']] = STA20df3['Away'].str.split('-',expand=True)
STA20df3[['Neutral_W', 'Neutral_L']] = STA20df3['Neutral'].str.split('-',expand=True)
STA20df3[['Top25_W', 'Top25_L']] = STA20df3['Top 25'].str.split('-',expand=True)
STA20df3 = STA20df3.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df4['Team'] = STA20df4['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rADEFGHIJKLNOPQRSTVWXYZ'))
STA20df4['Conf_W'] = pd.to_numeric(STA20df4["Conf_W"])
STA20df4['Conf_L'] = pd.to_numeric(STA20df4["Conf_L"])
STA20df4['W'] = pd.to_numeric(STA20df4['W'])
STA20df4['L'] = pd.to_numeric(STA20df4['L'])
STA20df4['Conf_PF'] = pd.to_numeric(STA20df4['Conf_PF'])
STA20df4['Conf_PA'] = pd.to_numeric(STA20df4['Conf_PA'])
STA20df4['PF'] = pd.to_numeric(STA20df4['PF'])
STA20df4['PA'] = pd.to_numeric(STA20df4['PA'])
STA20df4["Conf_PPG"] = STA20df4['Conf_PF']/(STA20df4['Conf_W'] + STA20df4['Conf_L'])
STA20df4["Conf_PAPG"] = STA20df4['Conf_PA']/(STA20df4['Conf_W'] + STA20df4['Conf_L'])
STA20df4['PPG'] = STA20df4['PF']/(STA20df4['W'] + STA20df4['L'])
STA20df4['PAPG'] = STA20df4['PA']/(STA20df4['W'] + STA20df4['L'])
STA20df4[['Home_W','Home_L']] = STA20df4['Home'].str.split('-',expand=True)
STA20df4[['Away_W','Away_L']] = STA20df4['Away'].str.split('-',expand=True)
STA20df4[['Neutral_W', 'Neutral_L']] = STA20df4['Neutral'].str.split('-',expand=True)
STA20df4[['Top25_W', 'Top25_L']] = STA20df4['Top 25'].str.split('-',expand=True)
STA20df4 = STA20df4.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df5['Team'] = STA20df5['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEHKLMOPQRSVWXYZ'))
STA20df5['Conf_W'] = pd.to_numeric(STA20df5["Conf_W"])
STA20df5['Conf_L'] = pd.to_numeric(STA20df5["Conf_L"])
STA20df5['W'] = pd.to_numeric(STA20df5['W'])
STA20df5['L'] = pd.to_numeric(STA20df5['L'])
STA20df5['Conf_PF'] = pd.to_numeric(STA20df5['Conf_PF'])
STA20df5['Conf_PA'] = pd.to_numeric(STA20df5['Conf_PA'])
STA20df5['PF'] = pd.to_numeric(STA20df5['PF'])
STA20df5['PA'] = pd.to_numeric(STA20df5['PA'])
STA20df5["Conf_PPG"] = STA20df5['Conf_PF']/(STA20df5['Conf_W'] + STA20df5['Conf_L'])
STA20df5["Conf_PAPG"] = STA20df5['Conf_PA']/(STA20df5['Conf_W'] + STA20df5['Conf_L'])
STA20df5['PPG'] = STA20df5['PF']/(STA20df5['W'] + STA20df5['L'])
STA20df5['PAPG'] = STA20df5['PA']/(STA20df5['W'] + STA20df5['L'])
STA20df5[['Home_W','Home_L']] = STA20df5['Home'].str.split('-',expand=True)
STA20df5[['Away_W','Away_L']] = STA20df5['Away'].str.split('-',expand=True)
STA20df5[['Neutral_W', 'Neutral_L']] = STA20df5['Neutral'].str.split('-',expand=True)
STA20df5[['Top25_W', 'Top25_L']] = STA20df5['Top 25'].str.split('-',expand=True)
STA20df5 = STA20df5.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df6['Team'] = STA20df6['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df6['Conf_W'] = pd.to_numeric(STA20df6["Conf_W"])
STA20df6['Conf_L'] = pd.to_numeric(STA20df6["Conf_L"])
STA20df6['W'] = pd.to_numeric(STA20df6['W'])
STA20df6['L'] = pd.to_numeric(STA20df6['L'])
STA20df6['Conf_PF'] = pd.to_numeric(STA20df6['Conf_PF'])
STA20df6['Conf_PA'] = pd.to_numeric(STA20df6['Conf_PA'])
STA20df6['PF'] = pd.to_numeric(STA20df6['PF'])
STA20df6['PA'] = pd.to_numeric(STA20df6['PA'])
STA20df6["Conf_PPG"] = STA20df6['Conf_PF']/(STA20df6['Conf_W'] + STA20df6['Conf_L'])
STA20df6["Conf_PAPG"] = STA20df6['Conf_PA']/(STA20df6['Conf_W'] + STA20df6['Conf_L'])
STA20df6['PPG'] = STA20df6['PF']/(STA20df6['W'] + STA20df6['L'])
STA20df6['PAPG'] = STA20df6['PA']/(STA20df6['W'] + STA20df6['L'])
STA20df6[['Home_W','Home_L']] = STA20df6['Home'].str.split('-',expand=True)
STA20df6[['Away_W','Away_L']] = STA20df6['Away'].str.split('-',expand=True)
STA20df6[['Neutral_W', 'Neutral_L']] = STA20df6['Neutral'].str.split('-',expand=True)
STA20df6[['Top25_W', 'Top25_L']] = STA20df6['Top 25'].str.split('-',expand=True)
STA20df6 = STA20df6.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df7['Team'] = STA20df7['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEFGHIJKLMNOPQRSVWXYZ-'))
STA20df7['Conf_W'] = pd.to_numeric(STA20df7["Conf_W"])
STA20df7['Conf_L'] = pd.to_numeric(STA20df7["Conf_L"])
STA20df7['W'] = pd.to_numeric(STA20df7['W'])
STA20df7['L'] = pd.to_numeric(STA20df7['L'])
STA20df7['Conf_PF'] = pd.to_numeric(STA20df7['Conf_PF'])
STA20df7['Conf_PA'] = pd.to_numeric(STA20df7['Conf_PA'])
STA20df7['PF'] = pd.to_numeric(STA20df7['PF'])
STA20df7['PA'] = pd.to_numeric(STA20df7['PA'])
STA20df7["Conf_PPG"] = STA20df7['Conf_PF']/(STA20df7['Conf_W'] + STA20df7['Conf_L'])
STA20df7["Conf_PAPG"] = STA20df7['Conf_PA']/(STA20df7['Conf_W'] + STA20df7['Conf_L'])
STA20df7['PPG'] = STA20df7['PF']/(STA20df7['W'] + STA20df7['L'])
STA20df7['PAPG'] = STA20df7['PA']/(STA20df7['W'] + STA20df7['L'])
STA20df7[['Home_W','Home_L']] = STA20df7['Home'].str.split('-',expand=True)
STA20df7[['Away_W','Away_L']] = STA20df7['Away'].str.split('-',expand=True)
STA20df7[['Neutral_W', 'Neutral_L']] = STA20df7['Neutral'].str.split('-',expand=True)
STA20df7[['Top25_W', 'Top25_L']] = STA20df7['Top 25'].str.split('-',expand=True)
STA20df7 = STA20df7.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df8['Team'] = STA20df8['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df8['Conf_W'] = pd.to_numeric(STA20df8["Conf_W"])
STA20df8['Conf_L'] = pd.to_numeric(STA20df8["Conf_L"])
STA20df8['W'] = pd.to_numeric(STA20df8['W'])
STA20df8['L'] = pd.to_numeric(STA20df8['L'])
STA20df8['Conf_PF'] = pd.to_numeric(STA20df8['Conf_PF'])
STA20df8['Conf_PA'] = pd.to_numeric(STA20df8['Conf_PA'])
STA20df8['PF'] = pd.to_numeric(STA20df8['PF'])
STA20df8['PA'] = pd.to_numeric(STA20df8['PA'])
STA20df8["Conf_PPG"] = STA20df8['Conf_PF']/(STA20df8['Conf_W'] + STA20df8['Conf_L'])
STA20df8["Conf_PAPG"] = STA20df8['Conf_PA']/(STA20df8['Conf_W'] + STA20df8['Conf_L'])
STA20df8['PPG'] = STA20df8['PF']/(STA20df8['W'] + STA20df8['L'])
STA20df8['PAPG'] = STA20df8['PA']/(STA20df8['W'] + STA20df8['L'])
STA20df8[['Home_W','Home_L']] = STA20df8['Home'].str.split('-',expand=True)
STA20df8[['Away_W','Away_L']] = STA20df8['Away'].str.split('-',expand=True)
STA20df8[['Neutral_W', 'Neutral_L']] = STA20df8['Neutral'].str.split('-',expand=True)
STA20df8[['Top25_W', 'Top25_L']] = STA20df8['Top 25'].str.split('-',expand=True)
STA20df8 = STA20df8.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df9['Team'] = STA20df9['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df9['Conf_W'] = pd.to_numeric(STA20df9["Conf_W"])
STA20df9['Conf_L'] = pd.to_numeric(STA20df9["Conf_L"])
STA20df9['W'] = pd.to_numeric(STA20df9['W'])
STA20df9['L'] = pd.to_numeric(STA20df9['L'])
STA20df9['Conf_PF'] = pd.to_numeric(STA20df9['Conf_PF'])
STA20df9['Conf_PA'] = pd.to_numeric(STA20df9['Conf_PA'])
STA20df9['PF'] = pd.to_numeric(STA20df9['PF'])
STA20df9['PA'] = pd.to_numeric(STA20df9['PA'])
STA20df9["Conf_PPG"] = STA20df9['Conf_PF']/(STA20df9['Conf_W'] + STA20df9['Conf_L'])
STA20df9["Conf_PAPG"] = STA20df9['Conf_PA']/(STA20df9['Conf_W'] + STA20df9['Conf_L'])
STA20df9['PPG'] = STA20df9['PF']/(STA20df9['W'] + STA20df9['L'])
STA20df9['PAPG'] = STA20df9['PA']/(STA20df9['W'] + STA20df9['L'])
STA20df9[['Home_W','Home_L']] = STA20df9['Home'].str.split('-',expand=True)
STA20df9[['Away_W','Away_L']] = STA20df9['Away'].str.split('-',expand=True)
STA20df9[['Neutral_W', 'Neutral_L']] = STA20df9['Neutral'].str.split('-',expand=True)
STA20df9[['Top25_W', 'Top25_L']] = STA20df9['Top 25'].str.split('-',expand=True)
STA20df9 = STA20df9.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df10['Team'] = STA20df10['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df10['Conf_W'] = pd.to_numeric(STA20df10["Conf_W"])
STA20df10['Conf_L'] = pd.to_numeric(STA20df10["Conf_L"])
STA20df10['W'] = pd.to_numeric(STA20df10['W'])
STA20df10['L'] = pd.to_numeric(STA20df10['L'])
STA20df10['Conf_PF'] = pd.to_numeric(STA20df10['Conf_PF'])
STA20df10['Conf_PA'] = pd.to_numeric(STA20df10['Conf_PA'])
STA20df10['PF'] = pd.to_numeric(STA20df10['PF'])
STA20df10['PA'] = pd.to_numeric(STA20df10['PA'])
STA20df10["Conf_PPG"] = STA20df10['Conf_PF']/(STA20df10['Conf_W'] + STA20df10['Conf_L'])
STA20df10["Conf_PAPG"] = STA20df10['Conf_PA']/(STA20df10['Conf_W'] + STA20df10['Conf_L'])
STA20df10['PPG'] = STA20df10['PF']/(STA20df10['W'] + STA20df10['L'])
STA20df10['PAPG'] = STA20df10['PA']/(STA20df10['W'] + STA20df10['L'])
STA20df10[['Home_W','Home_L']] = STA20df10['Home'].str.split('-',expand=True)
STA20df10[['Away_W','Away_L']] = STA20df10['Away'].str.split('-',expand=True)
STA20df10[['Neutral_W', 'Neutral_L']] = STA20df10['Neutral'].str.split('-',expand=True)
STA20df10[['Top25_W', 'Top25_L']] = STA20df10['Top 25'].str.split('-',expand=True)
STA20df10 = STA20df10.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df11['Team'] = STA20df11['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEFGHIJKLMOPQRTVWXYZ'))
STA20df11['Conf_W'] = pd.to_numeric(STA20df11["Conf_W"])
STA20df11['Conf_L'] = pd.to_numeric(STA20df11["Conf_L"])
STA20df11['W'] = pd.to_numeric(STA20df11['W'])
STA20df11['L'] = pd.to_numeric(STA20df11['L'])
STA20df11['Conf_PF'] = pd.to_numeric(STA20df11['Conf_PF'])
STA20df11['Conf_PA'] = pd.to_numeric(STA20df11['Conf_PA'])
STA20df11['PF'] = pd.to_numeric(STA20df11['PF'])
STA20df11['PA'] = pd.to_numeric(STA20df11['PA'])
STA20df11["Conf_PPG"] = STA20df11['Conf_PF']/(STA20df11['Conf_W'] + STA20df11['Conf_L'])
STA20df11["Conf_PAPG"] = STA20df11['Conf_PA']/(STA20df11['Conf_W'] + STA20df11['Conf_L'])
STA20df11['PPG'] = STA20df11['PF']/(STA20df11['W'] + STA20df11['L'])
STA20df11['PAPG'] = STA20df11['PA']/(STA20df11['W'] + STA20df11['L'])
STA20df11[['Home_W','Home_L']] = STA20df11['Home'].str.split('-',expand=True)
STA20df11[['Away_W','Away_L']] = STA20df11['Away'].str.split('-',expand=True)
STA20df11[['Neutral_W', 'Neutral_L']] = STA20df11['Neutral'].str.split('-',expand=True)
STA20df11[['Top25_W', 'Top25_L']] = STA20df11['Top 25'].str.split('-',expand=True)
STA20df11 = STA20df11.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df12['Team'] = STA20df12['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEFGHIJKLMOPQRSTVXYZ&'))
STA20df12['Conf_W'] = pd.to_numeric(STA20df12["Conf_W"])
STA20df12['Conf_L'] = pd.to_numeric(STA20df12["Conf_L"])
STA20df12['W'] = pd.to_numeric(STA20df12['W'])
STA20df12['L'] = pd.to_numeric(STA20df12['L'])
STA20df12['Conf_PF'] = pd.to_numeric(STA20df12['Conf_PF'])
STA20df12['Conf_PA'] = pd.to_numeric(STA20df12['Conf_PA'])
STA20df12['PF'] = pd.to_numeric(STA20df12['PF'])
STA20df12['PA'] = pd.to_numeric(STA20df12['PA'])
STA20df12["Conf_PPG"] = STA20df12['Conf_PF']/(STA20df12['Conf_W'] + STA20df12['Conf_L'])
STA20df12["Conf_PAPG"] = STA20df12['Conf_PA']/(STA20df12['Conf_W'] + STA20df12['Conf_L'])
STA20df12['PPG'] = STA20df12['PF']/(STA20df12['W'] + STA20df12['L'])
STA20df12['PAPG'] = STA20df12['PA']/(STA20df12['W'] + STA20df12['L'])
STA20df12[['Home_W','Home_L']] = STA20df12['Home'].str.split('-',expand=True)
STA20df12[['Away_W','Away_L']] = STA20df12['Away'].str.split('-',expand=True)
STA20df12[['Neutral_W', 'Neutral_L']] = STA20df12['Neutral'].str.split('-',expand=True)
STA20df12[['Top25_W', 'Top25_L']] = STA20df12['Top 25'].str.split('-',expand=True)
STA20df12 = STA20df12.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df13['Team'] = STA20df13['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('&\n \rCDGHJKLMNOQRVWXYZ'))
STA20df13['Conf_W'] = pd.to_numeric(STA20df13["Conf_W"])
STA20df13['Conf_L'] = pd.to_numeric(STA20df13["Conf_L"])
STA20df13['W'] = pd.to_numeric(STA20df13['W'])
STA20df13['L'] = pd.to_numeric(STA20df13['L'])
STA20df13['Conf_PF'] = pd.to_numeric(STA20df13['Conf_PF'])
STA20df13['Conf_PA'] = pd.to_numeric(STA20df13['Conf_PA'])
STA20df13['PF'] = pd.to_numeric(STA20df13['PF'])
STA20df13['PA'] = pd.to_numeric(STA20df13['PA'])
STA20df13["Conf_PPG"] = STA20df13['Conf_PF']/(STA20df13['Conf_W'] + STA20df13['Conf_L'])
STA20df13["Conf_PAPG"] = STA20df13['Conf_PA']/(STA20df13['Conf_W'] + STA20df13['Conf_L'])
STA20df13['PPG'] = STA20df13['PF']/(STA20df13['W'] + STA20df13['L'])
STA20df13['PAPG'] = STA20df13['PA']/(STA20df13['W'] + STA20df13['L'])
STA20df13[['Home_W','Home_L']] = STA20df13['Home'].str.split('-',expand=True)
STA20df13[['Away_W','Away_L']] = STA20df13['Away'].str.split('-',expand=True)
STA20df13[['Neutral_W', 'Neutral_L']] = STA20df13['Neutral'].str.split('-',expand=True)
STA20df13[['Top25_W', 'Top25_L']] = STA20df13['Top 25'].str.split('-',expand=True)
STA20df13 = STA20df13.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df14['Team'] = STA20df14['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEFGHJKLMNOQRSTVWXYZ'))
STA20df14['Conf_W'] = pd.to_numeric(STA20df14["Conf_W"])
STA20df14['Conf_L'] = pd.to_numeric(STA20df14["Conf_L"])
STA20df14['W'] = pd.to_numeric(STA20df14['W'])
STA20df14['L'] = pd.to_numeric(STA20df14['L'])
STA20df14['Conf_PF'] = pd.to_numeric(STA20df14['Conf_PF'])
STA20df14['Conf_PA'] = pd.to_numeric(STA20df14['Conf_PA'])
STA20df14['PF'] = pd.to_numeric(STA20df14['PF'])
STA20df14['PA'] = pd.to_numeric(STA20df14['PA'])
STA20df14["Conf_PPG"] = STA20df14['Conf_PF']/(STA20df14['Conf_W'] + STA20df14['Conf_L'])
STA20df14["Conf_PAPG"] = STA20df14['Conf_PA']/(STA20df14['Conf_W'] + STA20df14['Conf_L'])
STA20df14['PPG'] = STA20df14['PF']/(STA20df14['W'] + STA20df14['L'])
STA20df14['PAPG'] = STA20df14['PA']/(STA20df14['W'] + STA20df14['L'])
STA20df14[['Home_W','Home_L']] = STA20df14['Home'].str.split('-',expand=True)
STA20df14[['Away_W','Away_L']] = STA20df14['Away'].str.split('-',expand=True)
STA20df14[['Neutral_W', 'Neutral_L']] = STA20df14['Neutral'].str.split('-',expand=True)
STA20df14[['Top25_W', 'Top25_L']] = STA20df14['Top 25'].str.split('-',expand=True)
STA20df14 = STA20df14.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df15['Team'] = STA20df15['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df15['Conf_W'] = pd.to_numeric(STA20df15["Conf_W"])
STA20df15['Conf_L'] = pd.to_numeric(STA20df15["Conf_L"])
STA20df15['W'] = pd.to_numeric(STA20df15['W'])
STA20df15['L'] = pd.to_numeric(STA20df15['L'])
STA20df15['Conf_PF'] = pd.to_numeric(STA20df15['Conf_PF'])
STA20df15['Conf_PA'] = pd.to_numeric(STA20df15['Conf_PA'])
STA20df15['PF'] = pd.to_numeric(STA20df15['PF'])
STA20df15['PA'] = pd.to_numeric(STA20df15['PA'])
STA20df15["Conf_PPG"] = STA20df15['Conf_PF']/(STA20df15['Conf_W'] + STA20df15['Conf_L'])
STA20df15["Conf_PAPG"] = STA20df15['Conf_PA']/(STA20df15['Conf_W'] + STA20df15['Conf_L'])
STA20df15['PPG'] = STA20df15['PF']/(STA20df15['W'] + STA20df15['L'])
STA20df15['PAPG'] = STA20df15['PA']/(STA20df15['W'] + STA20df15['L'])
STA20df15[['Home_W','Home_L']] = STA20df15['Home'].str.split('-',expand=True)
STA20df15[['Away_W','Away_L']] = STA20df15['Away'].str.split('-',expand=True)
STA20df15[['Neutral_W', 'Neutral_L']] = STA20df15['Neutral'].str.split('-',expand=True)
STA20df15[['Top25_W', 'Top25_L']] = STA20df15['Top 25'].str.split('-',expand=True)
STA20df15 = STA20df15.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df16['Team'] = STA20df16['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df16['Conf_W'] = pd.to_numeric(STA20df16["Conf_W"])
STA20df16['Conf_L'] = pd.to_numeric(STA20df16["Conf_L"])
STA20df16['W'] = pd.to_numeric(STA20df16['W'])
STA20df16['L'] = pd.to_numeric(STA20df16['L'])
STA20df16['Conf_PF'] = pd.to_numeric(STA20df16['Conf_PF'])
STA20df16['Conf_PA'] = pd.to_numeric(STA20df16['Conf_PA'])
STA20df16['PF'] = pd.to_numeric(STA20df16['PF'])
STA20df16['PA'] = pd.to_numeric(STA20df16['PA'])
STA20df16["Conf_PPG"] = STA20df16['Conf_PF']/(STA20df16['Conf_W'] + STA20df16['Conf_L'])
STA20df16["Conf_PAPG"] = STA20df16['Conf_PA']/(STA20df16['Conf_W'] + STA20df16['Conf_L'])
STA20df16['PPG'] = STA20df16['PF']/(STA20df16['W'] + STA20df16['L'])
STA20df16['PAPG'] = STA20df16['PA']/(STA20df16['W'] + STA20df16['L'])
STA20df16[['Home_W','Home_L']] = STA20df16['Home'].str.split('-',expand=True)
STA20df16[['Away_W','Away_L']] = STA20df16['Away'].str.split('-',expand=True)
STA20df16[['Neutral_W', 'Neutral_L']] = STA20df16['Neutral'].str.split('-',expand=True)
STA20df16[['Top25_W', 'Top25_L']] = STA20df16['Top 25'].str.split('-',expand=True)
STA20df16 = STA20df16.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df17['Team'] = STA20df17['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ-'))
STA20df17['Conf_W'] = pd.to_numeric(STA20df17["Conf_W"])
STA20df17['Conf_L'] = pd.to_numeric(STA20df17["Conf_L"])
STA20df17['W'] = pd.to_numeric(STA20df17['W'])
STA20df17['L'] = pd.to_numeric(STA20df17['L'])
STA20df17['Conf_PF'] = pd.to_numeric(STA20df17['Conf_PF'])
STA20df17['Conf_PA'] = pd.to_numeric(STA20df17['Conf_PA'])
STA20df17['PF'] = pd.to_numeric(STA20df17['PF'])
STA20df17['PA'] = pd.to_numeric(STA20df17['PA'])
STA20df17["Conf_PPG"] = STA20df17['Conf_PF']/(STA20df17['Conf_W'] + STA20df17['Conf_L'])
STA20df17["Conf_PAPG"] = STA20df17['Conf_PA']/(STA20df17['Conf_W'] + STA20df17['Conf_L'])
STA20df17['PPG'] = STA20df17['PF']/(STA20df17['W'] + STA20df17['L'])
STA20df17['PAPG'] = STA20df17['PA']/(STA20df17['W'] + STA20df17['L'])
STA20df17[['Home_W','Home_L']] = STA20df17['Home'].str.split('-',expand=True)
STA20df17[['Away_W','Away_L']] = STA20df17['Away'].str.split('-',expand=True)
STA20df17[['Neutral_W', 'Neutral_L']] = STA20df17['Neutral'].str.split('-',expand=True)
STA20df17[['Top25_W', 'Top25_L']] = STA20df17['Top 25'].str.split('-',expand=True)
STA20df17 = STA20df17.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df18['Team'] = STA20df18['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df18['Conf_W'] = pd.to_numeric(STA20df18["Conf_W"])
STA20df18['Conf_L'] = pd.to_numeric(STA20df18["Conf_L"])
STA20df18['W'] = pd.to_numeric(STA20df18['W'])
STA20df18['L'] = pd.to_numeric(STA20df18['L'])
STA20df18['Conf_PF'] = pd.to_numeric(STA20df18['Conf_PF'])
STA20df18['Conf_PA'] = pd.to_numeric(STA20df18['Conf_PA'])
STA20df18['PF'] = pd.to_numeric(STA20df18['PF'])
STA20df18['PA'] = pd.to_numeric(STA20df18['PA'])
STA20df18["Conf_PPG"] = STA20df18['Conf_PF']/(STA20df18['Conf_W'] + STA20df18['Conf_L'])
STA20df18["Conf_PAPG"] = STA20df18['Conf_PA']/(STA20df18['Conf_W'] + STA20df18['Conf_L'])
STA20df18['PPG'] = STA20df18['PF']/(STA20df18['W'] + STA20df18['L'])
STA20df18['PAPG'] = STA20df18['PA']/(STA20df18['W'] + STA20df18['L'])
STA20df18[['Home_W','Home_L']] = STA20df18['Home'].str.split('-',expand=True)
STA20df18[['Away_W','Away_L']] = STA20df18['Away'].str.split('-',expand=True)
STA20df18[['Neutral_W', 'Neutral_L']] = STA20df18['Neutral'].str.split('-',expand=True)
STA20df18[['Top25_W', 'Top25_L']] = STA20df18['Top 25'].str.split('-',expand=True)
STA20df18 = STA20df18.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df19['Team'] = STA20df19['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHJKLMOPQRSTVWXYZ'))
STA20df19['Conf_W'] = pd.to_numeric(STA20df19["Conf_W"])
STA20df19['Conf_L'] = pd.to_numeric(STA20df19["Conf_L"])
STA20df19['W'] = pd.to_numeric(STA20df19['W'])
STA20df19['L'] = pd.to_numeric(STA20df19['L'])
STA20df19['Conf_PF'] = pd.to_numeric(STA20df19['Conf_PF'])
STA20df19['Conf_PA'] = pd.to_numeric(STA20df19['Conf_PA'])
STA20df19['PF'] = pd.to_numeric(STA20df19['PF'])
STA20df19['PA'] = pd.to_numeric(STA20df19['PA'])
STA20df19["Conf_PPG"] = STA20df19['Conf_PF']/(STA20df19['Conf_W'] + STA20df19['Conf_L'])
STA20df19["Conf_PAPG"] = STA20df19['Conf_PA']/(STA20df19['Conf_W'] + STA20df19['Conf_L'])
STA20df19['PPG'] = STA20df19['PF']/(STA20df19['W'] + STA20df19['L'])
STA20df19['PAPG'] = STA20df19['PA']/(STA20df19['W'] + STA20df19['L'])
STA20df19[['Home_W','Home_L']] = STA20df19['Home'].str.split('-',expand=True)
STA20df19[['Away_W','Away_L']] = STA20df19['Away'].str.split('-',expand=True)
STA20df19[['Neutral_W', 'Neutral_L']] = STA20df19['Neutral'].str.split('-',expand=True)
STA20df19[['Top25_W', 'Top25_L']] = STA20df19['Top 25'].str.split('-',expand=True)
STA20df19 = STA20df19.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df20['Team'] = STA20df20['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKMOPQRSTWXYZ'))
STA20df20['Conf_W'] = pd.to_numeric(STA20df20["Conf_W"])
STA20df20['Conf_L'] = pd.to_numeric(STA20df20["Conf_L"])
STA20df20['W'] = pd.to_numeric(STA20df20['W'])
STA20df20['L'] = pd.to_numeric(STA20df20['L'])
STA20df20['Conf_PF'] = pd.to_numeric(STA20df20['Conf_PF'])
STA20df20['Conf_PA'] = pd.to_numeric(STA20df20['Conf_PA'])
STA20df20['PF'] = pd.to_numeric(STA20df20['PF'])
STA20df20['PA'] = pd.to_numeric(STA20df20['PA'])
STA20df20["Conf_PPG"] = STA20df20['Conf_PF']/(STA20df20['Conf_W'] + STA20df20['Conf_L'])
STA20df20["Conf_PAPG"] = STA20df20['Conf_PA']/(STA20df20['Conf_W'] + STA20df20['Conf_L'])
STA20df20['PPG'] = STA20df20['PF']/(STA20df20['W'] + STA20df20['L'])
STA20df20['PAPG'] = STA20df20['PA']/(STA20df20['W'] + STA20df20['L'])
STA20df20[['Home_W','Home_L']] = STA20df20['Home'].str.split('-',expand=True)
STA20df20[['Away_W','Away_L']] = STA20df20['Away'].str.split('-',expand=True)
STA20df20[['Neutral_W', 'Neutral_L']] = STA20df20['Neutral'].str.split('-',expand=True)
STA20df20[['Top25_W', 'Top25_L']] = STA20df20['Top 25'].str.split('-',expand=True)
STA20df20 = STA20df20.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df21['Team'] = STA20df21['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHJKMNOPQRSTVWXYZ'))
STA20df21['Conf_W'] = pd.to_numeric(STA20df21["Conf_W"])
STA20df21['Conf_L'] = pd.to_numeric(STA20df21["Conf_L"])
STA20df21['W'] = pd.to_numeric(STA20df21['W'])
STA20df21['L'] = pd.to_numeric(STA20df21['L'])
STA20df21['Conf_PF'] = pd.to_numeric(STA20df21['Conf_PF'])
STA20df21['Conf_PA'] = pd.to_numeric(STA20df21['Conf_PA'])
STA20df21['PF'] = pd.to_numeric(STA20df21['PF'])
STA20df21['PA'] = pd.to_numeric(STA20df21['PA'])
STA20df21["Conf_PPG"] = STA20df21['Conf_PF']/(STA20df21['Conf_W'] + STA20df21['Conf_L'])
STA20df21["Conf_PAPG"] = STA20df21['Conf_PA']/(STA20df21['Conf_W'] + STA20df21['Conf_L'])
STA20df21['PPG'] = STA20df21['PF']/(STA20df21['W'] + STA20df21['L'])
STA20df21['PAPG'] = STA20df21['PA']/(STA20df21['W'] + STA20df21['L'])
STA20df21[['Home_W','Home_L']] = STA20df21['Home'].str.split('-',expand=True)
STA20df21[['Away_W','Away_L']] = STA20df21['Away'].str.split('-',expand=True)
STA20df21[['Neutral_W', 'Neutral_L']] = STA20df21['Neutral'].str.split('-',expand=True)
STA20df21[['Top25_W', 'Top25_L']] = STA20df21['Top 25'].str.split('-',expand=True)
STA20df21 = STA20df21.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df22['Team'] = STA20df22['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df22['Conf_W'] = pd.to_numeric(STA20df22["Conf_W"])
STA20df22['Conf_L'] = pd.to_numeric(STA20df22["Conf_L"])
STA20df22['W'] = pd.to_numeric(STA20df22['W'])
STA20df22['L'] = pd.to_numeric(STA20df22['L'])
STA20df22['Conf_PF'] = pd.to_numeric(STA20df22['Conf_PF'])
STA20df22['Conf_PA'] = pd.to_numeric(STA20df22['Conf_PA'])
STA20df22['PF'] = pd.to_numeric(STA20df22['PF'])
STA20df22['PA'] = pd.to_numeric(STA20df22['PA'])
STA20df22["Conf_PPG"] = STA20df22['Conf_PF']/(STA20df22['Conf_W'] + STA20df22['Conf_L'])
STA20df22["Conf_PAPG"] = STA20df22['Conf_PA']/(STA20df22['Conf_W'] + STA20df22['Conf_L'])
STA20df22['PPG'] = STA20df22['PF']/(STA20df22['W'] + STA20df22['L'])
STA20df22['PAPG'] = STA20df22['PA']/(STA20df22['W'] + STA20df22['L'])
STA20df22[['Home_W','Home_L']] = STA20df22['Home'].str.split('-',expand=True)
STA20df22[['Away_W','Away_L']] = STA20df22['Away'].str.split('-',expand=True)
STA20df22[['Neutral_W', 'Neutral_L']] = STA20df22['Neutral'].str.split('-',expand=True)
STA20df22[['Top25_W', 'Top25_L']] = STA20df22['Top 25'].str.split('-',expand=True)
STA20df22 = STA20df22.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df23['Team'] = STA20df23['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rBDEFGHIJKMNOPQRTVWXYZ'))
STA20df23['Conf_W'] = pd.to_numeric(STA20df23["Conf_W"])
STA20df23['Conf_L'] = pd.to_numeric(STA20df23["Conf_L"])
STA20df23['W'] = pd.to_numeric(STA20df23['W'])
STA20df23['L'] = pd.to_numeric(STA20df23['L'])
STA20df23['Conf_PF'] = pd.to_numeric(STA20df23['Conf_PF'])
STA20df23['Conf_PA'] = pd.to_numeric(STA20df23['Conf_PA'])
STA20df23['PF'] = pd.to_numeric(STA20df23['PF'])
STA20df23['PA'] = pd.to_numeric(STA20df23['PA'])
STA20df23["Conf_PPG"] = STA20df23['Conf_PF']/(STA20df23['Conf_W'] + STA20df23['Conf_L'])
STA20df23["Conf_PAPG"] = STA20df23['Conf_PA']/(STA20df23['Conf_W'] + STA20df23['Conf_L'])
STA20df23['PPG'] = STA20df23['PF']/(STA20df23['W'] + STA20df23['L'])
STA20df23['PAPG'] = STA20df23['PA']/(STA20df23['W'] + STA20df23['L'])
STA20df23[['Home_W','Home_L']] = STA20df23['Home'].str.split('-',expand=True)
STA20df23[['Away_W','Away_L']] = STA20df23['Away'].str.split('-',expand=True)
STA20df23[['Neutral_W', 'Neutral_L']] = STA20df23['Neutral'].str.split('-',expand=True)
STA20df23[['Top25_W', 'Top25_L']] = STA20df23['Top 25'].str.split('-',expand=True)
STA20df23 = STA20df23.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df24['Team'] = STA20df24['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df24['Conf_W'] = pd.to_numeric(STA20df24["Conf_W"])
STA20df24['Conf_L'] = pd.to_numeric(STA20df24["Conf_L"])
STA20df24['W'] = pd.to_numeric(STA20df24['W'])
STA20df24['L'] = pd.to_numeric(STA20df24['L'])
STA20df24['Conf_PF'] = pd.to_numeric(STA20df24['Conf_PF'])
STA20df24['Conf_PA'] = pd.to_numeric(STA20df24['Conf_PA'])
STA20df24['PF'] = pd.to_numeric(STA20df24['PF'])
STA20df24['PA'] = pd.to_numeric(STA20df24['PA'])
STA20df24["Conf_PPG"] = STA20df24['Conf_PF']/(STA20df24['Conf_W'] + STA20df24['Conf_L'])
STA20df24["Conf_PAPG"] = STA20df24['Conf_PA']/(STA20df24['Conf_W'] + STA20df24['Conf_L'])
STA20df24['PPG'] = STA20df24['PF']/(STA20df24['W'] + STA20df24['L'])
STA20df24['PAPG'] = STA20df24['PA']/(STA20df24['W'] + STA20df24['L'])
STA20df24[['Home_W','Home_L']] = STA20df24['Home'].str.split('-',expand=True)
STA20df24[['Away_W','Away_L']] = STA20df24['Away'].str.split('-',expand=True)
STA20df24[['Neutral_W', 'Neutral_L']] = STA20df24['Neutral'].str.split('-',expand=True)
STA20df24[['Top25_W', 'Top25_L']] = STA20df24['Top 25'].str.split('-',expand=True)
STA20df24 = STA20df24.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df25['Team'] = STA20df25['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKMNOPQRTVWXYZ'))
STA20df25['Conf_W'] = pd.to_numeric(STA20df25["Conf_W"])
STA20df25['Conf_L'] = pd.to_numeric(STA20df25["Conf_L"])
STA20df25['W'] = pd.to_numeric(STA20df25['W'])
STA20df25['L'] = pd.to_numeric(STA20df25['L'])
STA20df25['Conf_PF'] = pd.to_numeric(STA20df25['Conf_PF'])
STA20df25['Conf_PA'] = pd.to_numeric(STA20df25['Conf_PA'])
STA20df25['PF'] = pd.to_numeric(STA20df25['PF'])
STA20df25['PA'] = pd.to_numeric(STA20df25['PA'])
STA20df25["Conf_PPG"] = STA20df25['Conf_PF']/(STA20df25['Conf_W'] + STA20df25['Conf_L'])
STA20df25["Conf_PAPG"] = STA20df25['Conf_PA']/(STA20df25['Conf_W'] + STA20df25['Conf_L'])
STA20df25['PPG'] = STA20df25['PF']/(STA20df25['W'] + STA20df25['L'])
STA20df25['PAPG'] = STA20df25['PA']/(STA20df25['W'] + STA20df25['L'])
STA20df25[['Home_W','Home_L']] = STA20df25['Home'].str.split('-',expand=True)
STA20df25[['Away_W','Away_L']] = STA20df25['Away'].str.split('-',expand=True)
STA20df25[['Neutral_W', 'Neutral_L']] = STA20df25['Neutral'].str.split('-',expand=True)
STA20df25[['Top25_W', 'Top25_L']] = STA20df25['Top 25'].str.split('-',expand=True)
STA20df25 = STA20df25.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df26['Team'] = STA20df26['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEFHJKLOPQRSTWXYZ&'))
STA20df26['Conf_W'] = pd.to_numeric(STA20df26["Conf_W"])
STA20df26['Conf_L'] = pd.to_numeric(STA20df26["Conf_L"])
STA20df26['W'] = pd.to_numeric(STA20df26['W'])
STA20df26['L'] = pd.to_numeric(STA20df26['L'])
STA20df26['Conf_PF'] = pd.to_numeric(STA20df26['Conf_PF'])
STA20df26['Conf_PA'] = pd.to_numeric(STA20df26['Conf_PA'])
STA20df26['PF'] = pd.to_numeric(STA20df26['PF'])
STA20df26['PA'] = pd.to_numeric(STA20df26['PA'])
STA20df26["Conf_PPG"] = STA20df26['Conf_PF']/(STA20df26['Conf_W'] + STA20df26['Conf_L'])
STA20df26["Conf_PAPG"] = STA20df26['Conf_PA']/(STA20df26['Conf_W'] + STA20df26['Conf_L'])
STA20df26['PPG'] = STA20df26['PF']/(STA20df1['W'] + STA20df26['L'])
STA20df26['PAPG'] = STA20df26['PA']/(STA20df26['W'] + STA20df26['L'])
STA20df26[['Home_W','Home_L']] = STA20df26['Home'].str.split('-',expand=True)
STA20df26[['Away_W','Away_L']] = STA20df26['Away'].str.split('-',expand=True)
STA20df26[['Neutral_W', 'Neutral_L']] = STA20df26['Neutral'].str.split('-',expand=True)
STA20df26[['Top25_W', 'Top25_L']] = STA20df26['Top 25'].str.split('-',expand=True)
STA20df26 = STA20df26.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df27['Team'] = STA20df27['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df27['Conf_W'] = pd.to_numeric(STA20df27["Conf_W"])
STA20df27['Conf_L'] = pd.to_numeric(STA20df27["Conf_L"])
STA20df27['W'] = pd.to_numeric(STA20df27['W'])
STA20df27['L'] = pd.to_numeric(STA20df27['L'])
STA20df27['Conf_PF'] = pd.to_numeric(STA20df27['Conf_PF'])
STA20df27['Conf_PA'] = pd.to_numeric(STA20df27['Conf_PA'])
STA20df27['PF'] = pd.to_numeric(STA20df27['PF'])
STA20df27['PA'] = pd.to_numeric(STA20df27['PA'])
STA20df27["Conf_PPG"] = STA20df27['Conf_PF']/(STA20df27['Conf_W'] + STA20df27['Conf_L'])
STA20df27["Conf_PAPG"] = STA20df27['Conf_PA']/(STA20df27['Conf_W'] + STA20df27['Conf_L'])
STA20df27['PPG'] = STA20df27['PF']/(STA20df27['W'] + STA20df27['L'])
STA20df27['PAPG'] = STA20df27['PA']/(STA20df27['W'] + STA20df27['L'])
STA20df27[['Home_W','Home_L']] = STA20df27['Home'].str.split('-',expand=True)
STA20df27[['Away_W','Away_L']] = STA20df27['Away'].str.split('-',expand=True)
STA20df27[['Neutral_W', 'Neutral_L']] = STA20df27['Neutral'].str.split('-',expand=True)
STA20df27[['Top25_W', 'Top25_L']] = STA20df27['Top 25'].str.split('-',expand=True)
STA20df27 = STA20df27.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df28['Team'] = STA20df28['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEGHJKLMNOQRSTUVXYZ'))
STA20df28['Conf_W'] = pd.to_numeric(STA20df28["Conf_W"])
STA20df28['Conf_L'] = pd.to_numeric(STA20df28["Conf_L"])
STA20df28['W'] = pd.to_numeric(STA20df28['W'])
STA20df28['L'] = pd.to_numeric(STA20df28['L'])
STA20df28['Conf_PF'] = pd.to_numeric(STA20df28['Conf_PF'])
STA20df28['Conf_PA'] = pd.to_numeric(STA20df28['Conf_PA'])
STA20df28['PF'] = pd.to_numeric(STA20df28['PF'])
STA20df28['PA'] = pd.to_numeric(STA20df28['PA'])
STA20df28["Conf_PPG"] = STA20df28['Conf_PF']/(STA20df28['Conf_W'] + STA20df28['Conf_L'])
STA20df28["Conf_PAPG"] = STA20df28['Conf_PA']/(STA20df28['Conf_W'] + STA20df28['Conf_L'])
STA20df28['PPG'] = STA20df28['PF']/(STA20df28['W'] + STA20df28['L'])
STA20df28['PAPG'] = STA20df28['PA']/(STA20df28['W'] + STA20df28['L'])
STA20df28[['Home_W','Home_L']] = STA20df28['Home'].str.split('-',expand=True)
STA20df28[['Away_W','Away_L']] = STA20df28['Away'].str.split('-',expand=True)
STA20df28[['Neutral_W', 'Neutral_L']] = STA20df28['Neutral'].str.split('-',expand=True)
STA20df28[['Top25_W', 'Top25_L']] = STA20df28['Top 25'].str.split('-',expand=True)
STA20df28 = STA20df28.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df29['Team'] = STA20df29['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABCDEFGHIJKLMNOPQRSTUVWXYZ'))
STA20df29['Conf_W'] = pd.to_numeric(STA20df29["Conf_W"])
STA20df29['Conf_L'] = pd.to_numeric(STA20df29["Conf_L"])
STA20df29['W'] = pd.to_numeric(STA20df29['W'])
STA20df29['L'] = pd.to_numeric(STA20df29['L'])
STA20df29['Conf_PF'] = pd.to_numeric(STA20df29['Conf_PF'])
STA20df29['Conf_PA'] = pd.to_numeric(STA20df29['Conf_PA'])
STA20df29['PF'] = pd.to_numeric(STA20df29['PF'])
STA20df29['PA'] = pd.to_numeric(STA20df29['PA'])
STA20df29["Conf_PPG"] = STA20df29['Conf_PF']/(STA20df29['Conf_W'] + STA20df29['Conf_L'])
STA20df29["Conf_PAPG"] = STA20df29['Conf_PA']/(STA20df29['Conf_W'] + STA20df29['Conf_L'])
STA20df29['PPG'] = STA20df29['PF']/(STA20df29['W'] + STA20df29['L'])
STA20df29['PAPG'] = STA20df29['PA']/(STA20df29['W'] + STA20df29['L'])
STA20df29[['Home_W','Home_L']] = STA20df29['Home'].str.split('-',expand=True)
STA20df29[['Away_W','Away_L']] = STA20df29['Away'].str.split('-',expand=True)
STA20df29[['Neutral_W', 'Neutral_L']] = STA20df29['Neutral'].str.split('-',expand=True)
STA20df29[['Top25_W', 'Top25_L']] = STA20df29['Top 25'].str.split('-',expand=True)
STA20df29 = STA20df29.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df30['Team'] = STA20df30['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rCDEFGHIJKLMNOQRSTVWXYZ'))
STA20df30['Conf_W'] = pd.to_numeric(STA20df30["Conf_W"])
STA20df30['Conf_L'] = pd.to_numeric(STA20df30["Conf_L"])
STA20df30['W'] = pd.to_numeric(STA20df30['W'])
STA20df30['L'] = pd.to_numeric(STA20df30['L'])
STA20df30['Conf_PF'] = pd.to_numeric(STA20df30['Conf_PF'])
STA20df30['Conf_PA'] = pd.to_numeric(STA20df30['Conf_PA'])
STA20df30['PF'] = pd.to_numeric(STA20df30['PF'])
STA20df30['PA'] = pd.to_numeric(STA20df30['PA'])
STA20df30["Conf_PPG"] = STA20df30['Conf_PF']/(STA20df30['Conf_W'] + STA20df30['Conf_L'])
STA20df30["Conf_PAPG"] = STA20df30['Conf_PA']/(STA20df30['Conf_W'] + STA20df30['Conf_L'])
STA20df30['PPG'] = STA20df30['PF']/(STA20df30['W'] + STA20df30['L'])
STA20df30['PAPG'] = STA20df30['PA']/(STA20df30['W'] + STA20df30['L'])
STA20df30[['Home_W','Home_L']] = STA20df30['Home'].str.split('-',expand=True)
STA20df30[['Away_W','Away_L']] = STA20df30['Away'].str.split('-',expand=True)
STA20df30[['Neutral_W', 'Neutral_L']] = STA20df30['Neutral'].str.split('-',expand=True)
STA20df30[['Top25_W', 'Top25_L']] = STA20df30['Top 25'].str.split('-',expand=True)
STA20df30 = STA20df30.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df31['Team'] = STA20df31['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rABDEFGHIJLNOPQRSTVWXYZ'))
STA20df31['Conf_W'] = pd.to_numeric(STA20df31["Conf_W"])
STA20df31['Conf_L'] = pd.to_numeric(STA20df31["Conf_L"])
STA20df31['W'] = pd.to_numeric(STA20df31['W'])
STA20df31['L'] = pd.to_numeric(STA20df31['L'])
STA20df31['Conf_PF'] = pd.to_numeric(STA20df31['Conf_PF'])
STA20df31['Conf_PA'] = pd.to_numeric(STA20df31['Conf_PA'])
STA20df31['PF'] = pd.to_numeric(STA20df31['PF'])
STA20df31['PA'] = pd.to_numeric(STA20df31['PA'])
STA20df31["Conf_PPG"] = STA20df31['Conf_PF']/(STA20df31['Conf_W'] + STA20df31['Conf_L'])
STA20df31["Conf_PAPG"] = STA20df31['Conf_PA']/(STA20df31['Conf_W'] + STA20df31['Conf_L'])
STA20df31['PPG'] = STA20df31['PF']/(STA20df31['W'] + STA20df31['L'])
STA20df31['PAPG'] = STA20df31['PA']/(STA20df31['W'] + STA20df31['L'])
STA20df31[['Home_W','Home_L']] = STA20df31['Home'].str.split('-',expand=True)
STA20df31[['Away_W','Away_L']] = STA20df31['Away'].str.split('-',expand=True)
STA20df31[['Neutral_W', 'Neutral_L']] = STA20df31['Neutral'].str.split('-',expand=True)
STA20df31[['Top25_W', 'Top25_L']] = STA20df31['Top 25'].str.split('-',expand=True)
STA20df31 = STA20df31.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

STA20df32['Team'] = STA20df32['Team'].map(lambda x: x.lstrip('\n')).map(lambda x: x.rstrip('\n \rACDEFGHIJKLMNOPQRSTVWXZ'))
STA20df32['Conf_W'] = pd.to_numeric(STA20df32["Conf_W"])
STA20df32['Conf_L'] = pd.to_numeric(STA20df32["Conf_L"])
STA20df32['W'] = pd.to_numeric(STA20df32['W'])
STA20df32['L'] = pd.to_numeric(STA20df32['L'])
STA20df32['Conf_PF'] = pd.to_numeric(STA20df32['Conf_PF'])
STA20df32['Conf_PA'] = pd.to_numeric(STA20df32['Conf_PA'])
STA20df32['PF'] = pd.to_numeric(STA20df32['PF'])
STA20df32['PA'] = pd.to_numeric(STA20df32['PA'])
STA20df32["Conf_PPG"] = STA20df32['Conf_PF']/(STA20df32['Conf_W'] + STA20df32['Conf_L'])
STA20df32["Conf_PAPG"] = STA20df32['Conf_PA']/(STA20df32['Conf_W'] + STA20df32['Conf_L'])
STA20df32['PPG'] = STA20df32['PF']/(STA20df32['W'] + STA20df32['L'])
STA20df32['PAPG'] = STA20df32['PA']/(STA20df32['W'] + STA20df32['L'])
STA20df32[['Home_W','Home_L']] = STA20df32['Home'].str.split('-',expand=True)
STA20df32[['Away_W','Away_L']] = STA20df32['Away'].str.split('-',expand=True)
STA20df32[['Neutral_W', 'Neutral_L']] = STA20df32['Neutral'].str.split('-',expand=True)
STA20df32[['Top25_W', 'Top25_L']] = STA20df32['Top 25'].str.split('-',expand=True)
STA20df32 = STA20df32.drop('Home', axis = 1).drop('Away', axis = 1).drop('Neutral', axis = 1).drop('Top 25', axis = 1)

# %% [markdown]
# ## Rename Columns

# %%
##########
#2020FinalAPPoll
##########

AP20df.rename(columns={"Rnk": "AP20_Rnk", "Team": "AP20_Team", "W":"AP20_W", "L":"AP20_L"}, inplace = True)

# %%
##########
#2020KenPom
##########

KP20df.rename(columns={"Rank": "KP20_Rank", "Team": "KP20_Team", "Conference":"KP20_Conference", "Adjusted Efficiency Margin":"KP20_Ajusted Efficiency Margin","Adjusted Offensive Efficiency":"KP20_Adjusted Offensive Efficiency", "AOE Rk": "KP20_AOE Rk", "Adjusted Defensive Efficiency": "KP20_Adjusted Defensive Efficiency", "ADE Rk": "KP20_ADE Rk", "Adjusted Tempo": "KP20_Adjusted Tempo", "AT Rk": "KP20_AT Rk", "Luck": "KP20_Luck", "L Rk": "KP20_Luck Rk", "Strength of Schedule": "KP20_Strength of Schedule", "SOS Rk": "KP20_SOS Rk", "Average Opponents Offensive Efficiency": "KP20_Average Opponents Offensive Efficiency", "AOOE Rk": "KP20_AOOE Rk", "Average Opponents Defensive Efficiency": "KP20_Average Opponents Defensive Efficiency", "AODE Rk": "KP20_AODE Rk", "Non-Conference Strength of Schedule": "KP20_Non-Conference Strength of Schedule", "NCSOS Rk": "KP20_NCSOS Rk", "W": "KP20_W", "L": "KP20_L"}, inplace = True)

# %%
##########
#2020TeamStats
##########

TS20df.rename(columns={"TEAM": "TS20_Team", "GP": "TS20_GP", "PTS":"TS20_PTS", "FG%":"TS20_FG%", "3P%": "TS20_3P%", "FT%": "TS20_FT%", "FGM": "TS20_FGM", "FGA": "TS20_FGA", "3PM": "TS20_3PM", "3PA": "TS20_3PA", "FTM": "TS20_FTM", "FTA": "TS20_FTA"}, inplace = True)

# %%
##########
#2020PreSeasonAP
##########

PS20df.rename(columns={"Rnk": "PS20_Rnk", "Team": "PS20_Team"}, inplace = True)

# %%
##########
#2020Standings
##########

STA20df1.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df2.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df3.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df4.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df5.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df6.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df7.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df8.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df9.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df10.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df11.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df12.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df13.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df14.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df15.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df16.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df17.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df18.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df19.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df20.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df21.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df22.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df23.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df24.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df25.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df26.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df27.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df28.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df29.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df30.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df31.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)
STA20df32.rename(columns={"Team":"STA20_Team", "Conf_W":"STA20_Conf_W", "Conf_L":"STA20_Conf_L", "Conf_Pct":"STA20_Conf_Pct", "Conf_PF":"STA20_Conf_PF", "Conf_PA":"STA20_Conf_PA", "W":"STA20_W", "L":"STA20_L", "Pct":"STA20_Pct", "PF":"STA20_PF", "PA":"STA20_PA", "Strk":"STA20_Strk", "Conf_PPG":"STA20_Conf_PPG", "Conf_PAPG":"STA20_Conf_PAPG", "PPG":"STA20_PPG", "PAPG":"STA20_PAPG", "Home_W":"STA20_Home_W", "Home_L":"STA20_Home_L", "Away_W":"STA20_Away_W", "Away_L":"STA20_Away_L", "Neutral_W":"STA20_Neutral_W", "Neutral_L":"STA20_Neutral_L", "Top25_W":"STA20_Top25_W", "Top25_L":"STA20_Top25_L"}, inplace = True)

# %% [markdown]
# ## Save CSV's (HOME)

# %%
##########
#2020FinalAPPoll
##########

AP20df.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020APPoll.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
##########
#2020KenPom
##########

KP20df.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020KenPom.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
##########
#2020TeamStats
##########

TS20df.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020TeamStats.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
##########
#2020PreSeasonAP
##########

PS20df.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020PreSeasonAPPoll.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
##########
#2020Standings
##########

STA20dfs = [STA20df1, STA20df2, STA20df3, STA20df4, STA20df5, STA20df6, STA20df7, STA20df8, STA20df9, STA20df10, STA20df11, STA20df12, STA20df13, STA20df14, STA20df15, STA20df16, STA20df17, STA20df18, STA20df19, STA20df20, STA20df21, STA20df22, STA20df23, STA20df24, STA20df25, STA20df26, STA20df27, STA20df28, STA20df29, STA20df30, STA20df31, STA20df32]
count = 1
for df in STA20dfs:
    df.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\"+eval('STA20league'+str(count))+".csv", index = False, sep = ',', encoding = 'utf-8')
    count += 1

# %% [markdown]
# ## Get CSV's (HOME)

# %%
#########
#2020TeamStats
#########

TeamStats20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020TeamStats.csv")

# %%
#########
#2020APPoll
#########

APPoll20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020APPoll.csv")

# %%
#########
#2020KenPom
#########

KenPom20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020KenPom.csv")

# %%
#########
#2020PreSeasonAPPoll
#########

PSAPPoll20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020PreSeasonAPPoll.csv")

# %%
#########
#2020Standings
#########

AmericaEast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\America East.csv")
AmericanAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\American Athletic.csv")
Atlantic1020 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic 10.csv")
AtlanticCoast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic Coast.csv")
AtlanticSun20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic Sun.csv")
Big1220 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big 12.csv")
BigEast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big East.csv")
BigSky20  = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big Sky.csv")
BigSouth20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big South.csv")
BigTen20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big Ten.csv")
BigWest20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big West.csv")
Colonial20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Colonial.csv")
ConferenceUSA20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Conference USA.csv")
Horizon20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Horizon.csv")
Ivy20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Ivy.csv")
MetroAtlanticAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Metro Atlantic Athletic.csv")
MidEasternAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mid Eastern Athletic.csv")
MidAmerican20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mid-American.csv")
MissouriValley20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Missouri Valley.csv")
MountainWest20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mountain West.csv")
Northeast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Northeast.csv")
OhioValley20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Ohio Valley.csv")
Pacific1220 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Pacific 12.csv")
PatriotLeague20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Patriot League.csv")
Southeastern20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southeastern.csv")
Southern20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southern.csv")
Southland20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southland.csv")
SouthwesternAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southwestern Athletic.csv")
SummitLeague20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Summit League.csv")
SunBelt20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Sun Belt.csv")
WestCoast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\West Coast.csv")
WesternAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Western Athletic.csv")
Tables20 = [AmericaEast20, AmericanAthletic20, Atlantic1020, AtlanticCoast20, AtlanticSun20, Big1220, BigEast20, BigSky20, BigSouth20, BigTen20, BigWest20, Colonial20, ConferenceUSA20, Horizon20, Ivy20, MetroAtlanticAthletic20, MidEasternAthletic20, MidAmerican20, MissouriValley20, MountainWest20, Northeast20, OhioValley20, Pacific1220, PatriotLeague20, Southeastern20, Southern20, Southland20, SouthwesternAthletic20, SummitLeague20, SunBelt20, WestCoast20, WesternAthletic20]

# %% [markdown]
# ## Give TeamID's

# %%
#########
#2020APPoll
#########

APPoll20['TeamID'] = ''
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Gonzaga",'1',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "South Dakota State",'2',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Wright State",'3',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Green Bay",'4',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "New Mexico",'5',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "BYU",'6',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Utah State",'7',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Furman",'8',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Santa Clara",'9',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Winthrop",'10',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Florida",'11',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "South Dakota",'12',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Belmont",'13',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Florida International",'14',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "San Francisco",'15',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Sam Houston State",'16',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Portland State",'17',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Saint Mary's",'18',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Hofstra",'19',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Buffalo",'20',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Dakota",'21',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Colorado State",'22',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Samford",'23',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Georgia State",'24',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Coastal Carolina",'25',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Dayton",'26',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Duke",'27',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Long Island University",'28',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "CSU Northridge",'29',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UTSA",'30',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Austin Peay",'31',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Pacific",'32',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Marquette",'33',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Kent State",'34',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Georgetown",'35',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Boise State",'36',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Stephen F. Austin",'37',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Creighton",'38',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Seattle",'39',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "William & Mary",'40',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northern Kentucky",'41',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Delaware",'42',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "California Baptist",'43',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "East Tennessee State",'44',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Pepperdine",'45',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Omaha",'46',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Oregon",'47',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Nicholls",'48',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "McNeese",'49',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Iowa",'50',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "VMI",'51',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UMass Lowell",'52',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Georgia Southern",'53',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Morgan State",'54',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Rice",'55',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Tennessee State",'56',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Oral Roberts",'57',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UNLV",'58',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "St. John's",'59',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Air Force",'60',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "South Alabama",'61',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Texas",'62',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Sacred Heart",'63',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Colgate",'64',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Alabama",'65',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "San Diego State",'66',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Stony Brook",'67',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Central Michigan",'68',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Nevada",'69',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Youngstown St",'70',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Hampton",'71',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Murray State",'72',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Marshall",'73',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Eastern Kentucky",'74',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Arkansas State",'75',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Valparaiso",'76',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Penn State",'77',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Michigan State",'78',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UNC Greensboro",'79',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "St. Francis (PA)",'80',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Arizona",'81',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Toledo",'82',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Troy",'83',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Milwaukee",'84',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UC Irvine",'85',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Little Rock",'86',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UNC Wilmington",'87',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northeastern",'88',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Jacksonville State",'89',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Bradley",'90',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Purdue Fort Wayne",'91',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northern Iowa",'92',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Western Carolina",'93',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "The Citadel",'94',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Mercer",'95',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Dakota State",'96',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Eastern Illinois",'97',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Western Kentucky",'98',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Texas State",'99',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Drexel",'100',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Utah Valley",'101',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Detroit Mercy",'102',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Wofford",'103',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "NC State",'104',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "New Orleans",'105',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Richmond",'106',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Illinois",'107',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Florida Atlantic",'108',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "LSU",'109',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Loyola (MD)",'110',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Chattanooga",'111',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Middle Tennessee",'112',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "IUPUI",'113',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UC Davis",'114',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Louisiana Tech",'115',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Oregon State",'116',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Seton Hall",'117',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Washington State",'118',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "New Mexico State",'119',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Portland",'120',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "CSU Bakersfield",'121',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Bowling Green",'122',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UT Arlington",'123',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Long Beach State",'124',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Providence",'125',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "DePaul",'126',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Elon",'127',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Lamar",'128',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Auburn",'129',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Houston",'130',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Central Arkansas",'131',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Indiana",'132',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Bethune-Cookman",'133',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Louisville",'134',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Boston University",'135',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Charleston",'136',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Drake",'137',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Eastern Washington",'138',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Lipscomb",'139',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "San Diego",'140',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Denver",'141',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UIC",'142',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Washington",'143',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UNC Asheville",'144',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Towson",'145',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "James Madison",'146',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Chicago State",'147',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Wichita State",'148',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UMKC",'149',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Louisiana",'150',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Campbell",'151',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "USC",'152',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Grambling",'153',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UC Riverside",'154',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Syracuse",'155',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Georgia",'156',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Loyola Chicago",'157',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Morehead State",'158',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Akron",'159',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Michigan",'160',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Evansville",'161',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UMBC",'162',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Ohio State",'163',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Albany",'164',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Robert Morris",'165',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Cincinnati",'166',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Butler",'167',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Vermont",'168',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Kansas",'169',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "SMU",'170',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UT Martin",'171',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UTEP",'172',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Abilene Christian",'173',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "San JosÃ© St",'174',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Howard",'175',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Nebraska",'176',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Jacksonville",'177',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Carolina A&T",'178',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Bryant",'179',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Iowa State",'180',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Minnesota",'181',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Virginia Tech",'182',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UC Santa Barbara",'183',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Colorado",'184',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Bucknell",'185',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Saint Louis",'186',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "VCU",'187',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Appalachian State",'188',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Yale",'189',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Kentucky",'190',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Holy Cross",'191',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "South Carolina Upstate",'192',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Florida State",'193',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Maryland",'194',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Xavier",'195',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Notre Dame",'196',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Rutgers",'197',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Liberty",'198',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Longwood",'199',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Coppin State",'200',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Utah",'201',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Alabama",'202',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Purdue",'203',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Miami (OH)",'204',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Ohio",'205',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Southern Miss",'206',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Stetson",'207',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Villanova",'208',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Alcorn State",'209',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Tulsa",'210',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Memphis",'211',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "SIU-Edwardsville",'212',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Missouri State",'213',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Binghamton",'214',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Canisius",'215',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Oakland",'216',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "St. Francis (BKN)",'217',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Weber State",'218',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Florida",'219',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Arkansas",'220',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Hartford",'221',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Wisconsin",'222',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Saint Joseph's",'223',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Presbyterian",'224',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Loyola Marymount",'225',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Merrimack",'226',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Rhode Island",'227',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Cleveland State",'228',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Vanderbilt",'229',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Mississippi State",'230',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UMass",'231',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "West Virginia",'232',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Rider",'233',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Charleston Southern",'234',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Arizona State",'235',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "George Mason",'236',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Radford",'237',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UCLA",'238',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "SE Missouri St",'239',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Lehigh",'240',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Stanford",'241',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Texas Tech",'242',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Lafayette",'243',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "East Carolina",'244',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Florida Gulf Coast",'245',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Norfolk State",'246',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Wake Forest",'247',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Houston Baptist",'248',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Western Illinois",'249',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UAB",'250',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Oklahoma",'251',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Fresno State",'252',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "High Point",'253',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Grand Canyon",'254',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "CSU Fullerton",'255',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Miami",'256',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "American",'257',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northern Illinois",'258',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UT Rio Grande Valley",'259',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Ball State",'260',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "St. Bonaventure",'261',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Duquesne",'262',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Georgia Tech",'263',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Southern",'264',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Montana State",'265',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Carolina Central",'266',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Prairie View A&M",'267',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Army", '268',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Tennessee Tech",'269',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Indiana State",'270',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UConn",'271',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Hawai'i",'272',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Texas Southern",'273',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Pittsburgh",'274',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Old Dominion",'275',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Texas A&M-CC",'276',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "New Hampshire",'277',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Southern Utah",'278',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Fairleigh Dickinson",'279',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Davidson",'280',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "North Carolina",'281',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "George Washington",'282',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Central Connecticut",'283',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Tulane",'284',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Wyoming",'285',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Illinois State",'286',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "SE Louisiana",'287',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "South Carolina",'288',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Gardner-Webb",'289',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Southern Illinois",'290',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "TCU",'291',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Wagner",'292',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northern Colorado",'293',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Jackson State",'294',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Monmouth",'295',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UCF",'296',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "La Salle",'297',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Baylor",'298',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Clemson",'299',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Maine",'300',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Eastern Michigan",'301',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Temple",'302',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "NJIT",'303',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Montana",'304',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Boston College",'305',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Ole Miss",'306',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Siena",'307',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Delaware State",'308',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northwestern State",'309',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Mt. St. Mary's",'310',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Niagara",'311',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Charlotte",'312',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Oklahoma State",'313',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "South Carolina State",'314',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Missouri",'315',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Quinnipiac",'316',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northwestern",'317',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Tennessee",'318',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "South Florida",'319',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Texas",'320',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Harvard",'321',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Incarnate Word",'322',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Kansas State",'323',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Columbia",'324',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Idaho",'325',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Northern Arizona",'326',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "UL Monroe",'327',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "California",'328',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Navy",'329',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Cal Poly",'330',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Fairfield",'331',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Western Michigan",'332',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Maryland-Eastern Shore",'333',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Idaho State",'334',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Pennsylvania",'335',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Alabama State",'336',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Kennesaw State",'337',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Fordham",'338',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Marist",'339',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Florida A&M",'340',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Sacramento State",'341',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Alabama A&M",'342',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Texas A&M",'343',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Saint Peter's",'344',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Mississippi Valley State",'345',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Brown",'346',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Manhattan",'347',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Princeton",'348',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Virginia",'349',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Dartmouth",'350',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Iona",'351',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Cornell",'352',APPoll20.TeamID)
APPoll20['TeamID'] = np.where(APPoll20.AP20_Team == "Arkansas-Pine Bluff",'353',APPoll20.TeamID)

# %%
#########
#2020PreSeasonAPPoll
#########

PSAPPoll20['TeamID'] = ''
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Gonzaga",'1',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "South Dakota State",'2',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Wright State",'3',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Green Bay",'4',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "New Mexico",'5',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "BYU",'6',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Utah State",'7',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Furman",'8',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Santa Clara",'9',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Winthrop",'10',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Florida",'11',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "South Dakota",'12',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Belmont",'13',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Florida International",'14',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "San Francisco",'15',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Sam Houston State",'16',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Portland State",'17',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Saint Mary's",'18',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Hofstra",'19',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Buffalo",'20',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Dakota",'21',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Colorado State",'22',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Samford",'23',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Georgia State",'24',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Coastal Carolina",'25',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Dayton",'26',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Duke",'27',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Long Island University",'28',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "CSU Northridge",'29',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UTSA",'30',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Austin Peay",'31',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Pacific",'32',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Marquette",'33',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Kent State",'34',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Georgetown",'35',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Boise State",'36',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Stephen F. Austin",'37',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Creighton",'38',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Seattle",'39',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "William & Mary",'40',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northern Kentucky",'41',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Delaware",'42',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "California Baptist",'43',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "East Tennessee State",'44',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Pepperdine",'45',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Omaha",'46',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Oregon",'47',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Nicholls",'48',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "McNeese",'49',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Iowa",'50',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "VMI",'51',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UMass Lowell",'52',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Georgia Southern",'53',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Morgan State",'54',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Rice",'55',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Tennessee State",'56',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Oral Roberts",'57',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UNLV",'58',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "St. John's",'59',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Air Force",'60',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "South Alabama",'61',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Texas",'62',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Sacred Heart",'63',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Colgate",'64',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Alabama",'65',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "San Diego State",'66',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Stony Brook",'67',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Central Michigan",'68',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Nevada",'69',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Youngstown St",'70',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Hampton",'71',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Murray State",'72',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Marshall",'73',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Eastern Kentucky",'74',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Arkansas State",'75',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Valparaiso",'76',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Penn State",'77',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Michigan State",'78',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UNC Greensboro",'79',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "St. Francis (PA)",'80',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Arizona",'81',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Toledo",'82',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Troy",'83',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Milwaukee",'84',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UC Irvine",'85',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Little Rock",'86',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UNC Wilmington",'87',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northeastern",'88',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Jacksonville State",'89',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Bradley",'90',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Purdue Fort Wayne",'91',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northern Iowa",'92',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Western Carolina",'93',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "The Citadel",'94',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Mercer",'95',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Dakota State",'96',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Eastern Illinois",'97',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Western Kentucky",'98',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Texas State",'99',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Drexel",'100',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Utah Valley",'101',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Detroit Mercy",'102',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Wofford",'103',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "NC State",'104',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "New Orleans",'105',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Richmond",'106',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Illinois",'107',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Florida Atlantic",'108',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "LSU",'109',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Loyola (MD)",'110',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Chattanooga",'111',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Middle Tennessee",'112',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "IUPUI",'113',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UC Davis",'114',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Louisiana Tech",'115',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Oregon State",'116',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Seton Hall",'117',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Washington State",'118',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "New Mexico State",'119',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Portland",'120',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "CSU Bakersfield",'121',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Bowling Green",'122',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UT Arlington",'123',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Long Beach State",'124',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Providence",'125',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "DePaul",'126',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Elon",'127',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Lamar",'128',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Auburn",'129',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Houston",'130',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Central Arkansas",'131',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Indiana",'132',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Bethune-Cookman",'133',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Louisville",'134',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Boston University",'135',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Charleston",'136',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Drake",'137',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Eastern Washington",'138',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Lipscomb",'139',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "San Diego",'140',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Denver",'141',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UIC",'142',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Washington",'143',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UNC Asheville",'144',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Towson",'145',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "James Madison",'146',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Chicago State",'147',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Wichita State",'148',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UMKC",'149',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Louisiana",'150',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Campbell",'151',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "USC",'152',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Grambling",'153',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UC Riverside",'154',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Syracuse",'155',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Georgia",'156',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Loyola Chicago",'157',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Morehead State",'158',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Akron",'159',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Michigan",'160',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Evansville",'161',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UMBC",'162',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Ohio State",'163',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Albany",'164',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Robert Morris",'165',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Cincinnati",'166',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Butler",'167',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Vermont",'168',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Kansas",'169',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "SMU",'170',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UT Martin",'171',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UTEP",'172',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Abilene Christian",'173',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "San JosÃ© St",'174',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Howard",'175',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Nebraska",'176',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Jacksonville",'177',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Carolina A&T",'178',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Bryant",'179',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Iowa State",'180',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Minnesota",'181',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Virginia Tech",'182',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UC Santa Barbara",'183',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Colorado",'184',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Bucknell",'185',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Saint Louis",'186',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "VCU",'187',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Appalachian State",'188',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Yale",'189',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Kentucky",'190',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Holy Cross",'191',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "South Carolina Upstate",'192',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Florida State",'193',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Maryland",'194',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Xavier",'195',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Notre Dame",'196',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Rutgers",'197',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Liberty",'198',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Longwood",'199',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Coppin State",'200',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Utah",'201',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Alabama",'202',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Purdue",'203',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Miami (OH)",'204',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Ohio",'205',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Southern Miss",'206',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Stetson",'207',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Villanova",'208',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Alcorn State",'209',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Tulsa",'210',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Memphis",'211',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "SIU-Edwardsville",'212',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Missouri State",'213',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Binghamton",'214',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Canisius",'215',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Oakland",'216',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "St. Francis (BKN)",'217',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Weber State",'218',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Florida",'219',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Arkansas",'220',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Hartford",'221',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Wisconsin",'222',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Saint Joseph's",'223',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Presbyterian",'224',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Loyola Marymount",'225',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Merrimack",'226',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Rhode Island",'227',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Cleveland State",'228',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Vanderbilt",'229',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Mississippi State",'230',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UMass",'231',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "West Virginia",'232',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Rider",'233',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Charleston Southern",'234',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Arizona State",'235',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "George Mason",'236',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Radford",'237',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UCLA",'238',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "SE Missouri St",'239',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Lehigh",'240',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Stanford",'241',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Texas Tech",'242',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Lafayette",'243',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "East Carolina",'244',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Florida Gulf Coast",'245',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Norfolk State",'246',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Wake Forest",'247',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Houston Baptist",'248',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Western Illinois",'249',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UAB",'250',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Oklahoma",'251',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Fresno State",'252',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "High Point",'253',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Grand Canyon",'254',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "CSU Fullerton",'255',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Miami",'256',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "American",'257',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northern Illinois",'258',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UT Rio Grande Valley",'259',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Ball State",'260',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "St. Bonaventure",'261',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Duquesne",'262',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Georgia Tech",'263',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Southern",'264',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Montana State",'265',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Carolina Central",'266',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Prairie View A&M",'267',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Army", '268',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Tennessee Tech",'269',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Indiana State",'270',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UConn",'271',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Hawai'i",'272',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Texas Southern",'273',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Pittsburgh",'274',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Old Dominion",'275',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Texas A&M-CC",'276',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "New Hampshire",'277',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Southern Utah",'278',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Fairleigh Dickinson",'279',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Davidson",'280',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "North Carolina",'281',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "George Washington",'282',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Central Connecticut",'283',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Tulane",'284',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Wyoming",'285',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Illinois State",'286',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "SE Louisiana",'287',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "South Carolina",'288',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Gardner-Webb",'289',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Southern Illinois",'290',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "TCU",'291',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Wagner",'292',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northern Colorado",'293',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Jackson State",'294',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Monmouth",'295',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UCF",'296',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "La Salle",'297',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Baylor",'298',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Clemson",'299',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Maine",'300',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Eastern Michigan",'301',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Temple",'302',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "NJIT",'303',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Montana",'304',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Boston College",'305',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Ole Miss",'306',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Siena",'307',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Delaware State",'308',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northwestern State",'309',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Mt. St. Mary's",'310',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Niagara",'311',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Charlotte",'312',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Oklahoma State",'313',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "South Carolina State",'314',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Missouri",'315',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Quinnipiac",'316',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northwestern",'317',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Tennessee",'318',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "South Florida",'319',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Texas",'320',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Harvard",'321',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Incarnate Word",'322',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Kansas State",'323',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Columbia",'324',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Idaho",'325',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Northern Arizona",'326',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "UL Monroe",'327',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "California",'328',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Navy",'329',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Cal Poly",'330',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Fairfield",'331',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Western Michigan",'332',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Maryland-Eastern Shore",'333',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Idaho State",'334',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Pennsylvania",'335',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Alabama State",'336',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Kennesaw State",'337',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Fordham",'338',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Marist",'339',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Florida A&M",'340',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Sacramento State",'341',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Alabama A&M",'342',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Texas A&M",'343',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Saint Peter's",'344',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Mississippi Valley State",'345',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Brown",'346',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Manhattan",'347',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Princeton",'348',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Virginia",'349',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Dartmouth",'350',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Iona",'351',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Cornell",'352',PSAPPoll20.TeamID)
PSAPPoll20['TeamID'] = np.where(PSAPPoll20.PS20_Team == "Arkansas-Pine Bluff",'353',PSAPPoll20.TeamID)

# %%
#########
#2020TeamStats
#########

TeamStats20['TeamID'] = ''
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Gonzaga",'1',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "South Dakota State",'2',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Wright State",'3',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Green Bay",'4',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "New Mexico",'5',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "BYU",'6',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Utah State",'7',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Furman",'8',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Santa Clara",'9',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Winthrop",'10',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Florida",'11',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "South Dakota",'12',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Belmont",'13',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Florida International",'14',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "San Francisco",'15',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Sam Houston State",'16',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Portland State",'17',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Saint Mary's",'18',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Hofstra",'19',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Buffalo",'20',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Dakota",'21',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Colorado State",'22',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Samford",'23',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Georgia State",'24',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Coastal Carolina",'25',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Dayton",'26',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Duke",'27',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Long Island University",'28',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "CSU Northridge",'29',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UTSA",'30',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Austin Peay",'31',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Pacific",'32',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Marquette",'33',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Kent State",'34',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Georgetown",'35',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Boise State",'36',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Stephen F. Austin",'37',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Creighton",'38',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Seattle",'39',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "William & Mary",'40',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northern Kentucky",'41',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Delaware",'42',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "California Baptist",'43',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "East Tennessee State",'44',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Pepperdine",'45',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Omaha",'46',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Oregon",'47',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Nicholls",'48',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "McNeese",'49',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Iowa",'50',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "VMI",'51',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UMass Lowell",'52',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Georgia Southern",'53',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Morgan State",'54',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Rice",'55',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Tennessee State",'56',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Oral Roberts",'57',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UNLV",'58',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "St. John's",'59',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Air Force",'60',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "South Alabama",'61',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Texas",'62',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Sacred Heart",'63',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Colgate",'64',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Alabama",'65',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "San Diego State",'66',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Stony Brook",'67',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Central Michigan",'68',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Nevada",'69',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Youngstown St",'70',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Hampton",'71',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Murray State",'72',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Marshall",'73',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Eastern Kentucky",'74',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Arkansas St",'75',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Valparaiso",'76',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Penn State",'77',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Michigan State",'78',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UNC Greensboro",'79',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "St. Francis (PA)",'80',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Arizona",'81',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Toledo",'82',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Troy",'83',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Milwaukee",'84',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UC Irvine",'85',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Little Rock",'86',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UNC Wilmington",'87',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northeastern",'88',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Jacksonville State",'89',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Bradley",'90',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Purdue Fort Wayne",'91',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northern Iowa",'92',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Western Carolina",'93',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "The Citadel",'94',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Mercer",'95',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Dakota State",'96',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Eastern Illinois",'97',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Western Kentucky",'98',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Texas State",'99',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Drexel",'100',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Utah Valley",'101',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Detroit Mercy",'102',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Wofford",'103',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "NC State",'104',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "New Orleans",'105',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Richmond",'106',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Illinois",'107',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Florida Atlantic",'108',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "LSU",'109',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Loyola (MD)",'110',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Chattanooga",'111',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Middle Tennessee",'112',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "IUPUI",'113',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UC Davis",'114',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Louisiana Tech",'115',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Oregon State",'116',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Seton Hall",'117',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Washington State",'118',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "New Mexico State",'119',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Portland",'120',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "CSU Bakersfield",'121',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Bowling Green",'122',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UT Arlington",'123',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Long Beach State",'124',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Providence",'125',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "DePaul",'126',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Elon",'127',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Lamar",'128',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Auburn",'129',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Houston",'130',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Central Arkansas",'131',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Indiana",'132',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Bethune-Cookman",'133',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Louisville",'134',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Boston Univ.",'135',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Charleston",'136',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Drake",'137',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Eastern Washington",'138',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Lipscomb",'139',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "San Diego",'140',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Denver",'141',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UIC",'142',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Washington",'143',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UNC Asheville",'144',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Towson",'145',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "James Madison",'146',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Chicago State",'147',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Wichita State",'148',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UMKC",'149',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Louisiana",'150',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Campbell",'151',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "USC",'152',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Grambling",'153',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UC Riverside",'154',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Syracuse",'155',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Georgia",'156',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Loyola Chicago",'157',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Morehead State",'158',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Akron",'159',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Michigan",'160',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Evansville",'161',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UMBC",'162',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Ohio State",'163',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Albany",'164',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Robert Morris",'165',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Cincinnati",'166',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Butler",'167',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Vermont",'168',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Kansas",'169',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "SMU",'170',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UT Martin",'171',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UTEP",'172',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Abilene Christian",'173',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "San José St",'174',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Howard",'175',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Nebraska",'176',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Jacksonville",'177',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Carolina A&T",'178',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Bryant",'179',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Iowa State",'180',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Minnesota",'181',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Virginia Tech",'182',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UC Santa Barbara",'183',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Colorado",'184',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Bucknell",'185',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Saint Louis",'186',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "VCU",'187',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Appalachian State",'188',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Yale",'189',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Kentucky",'190',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Holy Cross",'191',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "South Carolina Upstate",'192',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Florida State",'193',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Maryland",'194',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Xavier",'195',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Notre Dame",'196',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Rutgers",'197',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Liberty",'198',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Longwood",'199',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Coppin State",'200',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Utah",'201',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Alabama",'202',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Purdue",'203',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Miami (OH)",'204',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Ohio",'205',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Southern Miss",'206',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Stetson",'207',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Villanova",'208',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Alcorn State",'209',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Tulsa",'210',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Memphis",'211',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "SIU-Edwardsville",'212',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Missouri State",'213',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Binghamton",'214',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Canisius",'215',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Oakland",'216',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "St. Francis (BKN)",'217',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Weber State",'218',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Florida",'219',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Arkansas",'220',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Hartford",'221',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Wisconsin",'222',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Saint Joseph's",'223',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Presbyterian",'224',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Loyola Marymount",'225',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Merrimack",'226',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Rhode Island",'227',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Cleveland State",'228',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Vanderbilt",'229',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Mississippi State",'230',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UMass",'231',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "West Virginia",'232',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Rider",'233',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Charleston Southern",'234',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Arizona State",'235',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "George Mason",'236',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Radford",'237',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UCLA",'238',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "SE Missouri St",'239',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Lehigh",'240',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Stanford",'241',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Texas Tech",'242',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Lafayette",'243',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "East Carolina",'244',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Florida Gulf Coast",'245',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Norfolk State",'246',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Wake Forest",'247',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Houston Baptist",'248',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Western Illinois",'249',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UAB",'250',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Oklahoma",'251',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Fresno State",'252',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "High Point",'253',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Grand Canyon",'254',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "CSU Fullerton",'255',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Miami",'256',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "American",'257',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northern Illinois",'258',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UT Rio Grande Valley",'259',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Ball State",'260',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "St. Bonaventure",'261',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Duquesne",'262',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Georgia Tech",'263',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Southern",'264',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Montana State",'265',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Carolina Central",'266',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Prairie View A&M",'267',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Army", '268',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Tennessee Tech",'269',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Indiana State",'270',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UConn",'271',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Hawai'i",'272',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Texas Southern",'273',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Pittsburgh",'274',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Old Dominion",'275',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Texas A&M-CC",'276',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "New Hampshire",'277',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Southern Utah",'278',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Fairleigh Dickinson",'279',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Davidson",'280',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "North Carolina",'281',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "George Washington",'282',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Central Connecticut",'283',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Tulane",'284',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Wyoming",'285',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Illinois State",'286',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "SE Louisiana",'287',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "South Carolina",'288',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Gardner-Webb",'289',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Southern Illinois",'290',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "TCU",'291',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Wagner",'292',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northern Colorado",'293',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Jackson State",'294',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Monmouth",'295',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UCF",'296',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "La Salle",'297',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Baylor",'298',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Clemson",'299',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Maine",'300',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Eastern Michigan",'301',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Temple",'302',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "NJIT",'303',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Montana",'304',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Boston College",'305',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Ole Miss",'306',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Siena",'307',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Delaware State",'308',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northwestern State",'309',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Mt. St. Mary's",'310',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Niagara",'311',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Charlotte",'312',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Oklahoma State",'313',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "South Carolina State",'314',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Missouri",'315',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Quinnipiac",'316',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northwestern",'317',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Tennessee",'318',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "South Florida",'319',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Texas",'320',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Harvard",'321',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Incarnate Word",'322',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Kansas State",'323',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Columbia",'324',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Idaho",'325',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Northern Arizona",'326',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "UL Monroe",'327',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "California",'328',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Navy",'329',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Cal Poly",'330',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Fairfield",'331',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Western Michigan",'332',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Maryland-Eastern Shore",'333',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Idaho State",'334',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Pennsylvania",'335',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Alabama State",'336',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Kennesaw State",'337',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Fordham",'338',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Marist",'339',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Florida A&M",'340',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Sacramento State",'341',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Alabama A&M",'342',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Texas A&M",'343',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Saint Peter's",'344',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Mississippi Valley State",'345',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Brown",'346',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Manhattan",'347',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Princeton",'348',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Virginia",'349',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Dartmouth",'350',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Iona",'351',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Cornell",'352',TeamStats20.TeamID)
TeamStats20['TeamID'] = np.where(TeamStats20.TS20_Team == "Arkansas-Pine Bluff",'353',TeamStats20.TeamID)

# %%
#########
#2020Standings
#########

for table in Tables20:
    table['TeamID'] = ''
    table['TeamID'] = np.where(table.STA20_Team == "Gonzaga",'1',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "South Dakota St",'2',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Wright State",'3',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Green Bay",'4',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "New Mexico\nUN",'5',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "BYU\nBYU",'6',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Utah State\nUSU",'7',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Furman\nFU",'8',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Santa Clara\nSCU",'9',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Winthrop",'10',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "North Florida\nUNF",'11',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "South Dakota",'12',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Belmont",'13',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "FIU\nFIU",'14',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "San Francisco",'15',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Sam Houston State",'16',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Portland State",'17',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Saint Mary's",'18',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Hofstra",'19',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Buffalo",'20',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "North Dakota",'21',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Colorado State\nCSU",'22',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Samford\nSAM",'23',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Georgia State",'24',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Coastal Carolina",'25',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Dayton",'26',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Duke",'27',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "LIU Brooklyn\nLIU",'28',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "CSUN\nCSN",'29',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UTSA\nUTSA",'30',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Austin Peay",'31',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Pacific",'32',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Marquette",'33',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Kent State",'34',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Georgetown",'35',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Boise State\nBSU",'36',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Stephen F Austin",'37',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Creighton",'38',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Seattle",'39',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "William & Mary\nW",'40',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Northern Kentucky\nNKU",'41',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Delaware",'42',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "California Baptist\nCBU",'43',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "E Tennessee State\nETSU",'44',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Pepperdine",'45',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Omaha",'46',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Oregon",'47',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Nicholls State",'48',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "McNeese State",'49',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Iowa",'50',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "VMI\nVMI",'51',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UMass Lowell\nM",'52',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Ga Southern",'53',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Morgan State",'54',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Rice\nRICE",'55',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Tennessee State",'56',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Oral Roberts",'57',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UNLV\nUNLV",'58',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "St John's",'59',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Air Force",'60',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "South Alabama",'61',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "North Texas\nUNT",'62',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Sacred Heart\nSHU",'63',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Colgate",'64',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Alabama\nAL",'65',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "San Diego State\nSDSU",'66',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Stony Brook",'67',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Central Michigan",'68',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Nevada\nNEV",'69',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Youngstown State\nYSU",'70',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Hampton",'71',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Murray State",'72',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Marshall\nMRS",'73',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Eastern Kentucky",'74',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Arkansas State",'75',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Valparaiso",'76',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Penn State",'77',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Michigan State",'78',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UNCG\nUNCG",'79',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Saint Francis U",'80',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Arizona\nA",'81',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Toledo",'82',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Troy",'83',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Milwaukee\nMI",'84',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UC Irvine\nUC",'85',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Little Rock",'86',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UNCW\nUNCW",'87',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Northeastern\nN",'88',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Jacksonville St",'89',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Bradley",'90',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "IPFW\nPFW",'91',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UNI\nUNI",'92',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Western Carolina\nWCU",'93',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Citadel\nCI",'94',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Mercer\nM",'95',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "North Dakota St",'96',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Eastern Illinois",'97',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Western Kentucky\nWKU",'98',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Texas State",'99',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Drexel",'100',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Utah Valley\nUVU",'101',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Detroit",'102',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Wofford",'103',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "North Carolina St",'104',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "New Orleans",'105',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Richmond\nRIC",'106',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Illinois",'107',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Florida Atlantic\nFAU",'108',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "LSU\nLSU",'109',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Loyola (MD)\nL-",'110',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Chattanooga\nC",'111',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Middle Tennessee\nMTU",'112',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "IUPUI\nIUPU",'113',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UC Davis\nUC",'114',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Louisiana Tech\nLT",'115',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Oregon State\nORS",'116',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Seton Hall",'117',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Washington State\nWSU",'118',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "New Mexico State\nNMSU",'119',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Portland",'120',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Bakersfield\nC",'121',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Bowling Green",'122',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UT Arlington",'123',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Long Beach State\nLBSU",'124',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Providence",'125',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "DePaul",'126',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Elon\nELON",'127',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Lamar",'128',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Auburn\nAU",'129',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Houston\nHOU",'130',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Central Arkansas",'131',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Indiana",'132',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Bethune-Cookman",'133',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Louisville",'134',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Boston",'135',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Charleston\nCOFC",'136',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Drake",'137',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "E Washington",'138',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Lipscomb\nLI",'139',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "San Diego\nU",'140',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Denver",'141',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UIC\nUIC",'142',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Washington\nWAS",'143',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UNC Asheville",'144',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Towson\nTOW",'145',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "James Madison\nJMU",'146',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Chicago State\nC",'147',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Wichita State\nWIC",'148',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UMKC\nUMKC", '149',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Louisiana-Lafayette",'150',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Campbell",'151',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "USC\nUSC",'152',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Grambling State\nGRA",'153',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UC Riverside\nUC",'154',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Syracuse",'155',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Georgia\nU",'156',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Loyola (CHI)\nL-I",'157',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Morehead State",'158',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Akron",'159',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Michigan",'160',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Evansville\nEVAN",'161',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UMBC\nUMBC",'162',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Ohio State",'163',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Albany\nALB",'164',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Robert Morris\nRMU",'165',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Cincinnati\nC",'166',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Butler",'167',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Vermont\nUVM",'168',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Kansas\nKU",'169',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "SMU\nSMU",'170',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UT Martin",'171',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UTEP\nUTEP",'172',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Abilene Christian",'173',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "San Jose State\nSJSU",'174',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Howard",'175',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Nebraska",'176',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Jacksonville\nJAC",'177',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "N Carolina A&",'178',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Bryant",'179',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Iowa State\nISU",'180',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Minnesota",'181',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Virginia Tech",'182',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UC Santa Barbara\nUCS",'183',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Colorado\nCOL",'184',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Bucknell",'185',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Saint Louis\nSLU",'186',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "VCU\nVCU",'187',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Appalachian State",'188',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Yale",'189',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Kentucky\nU",'190',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Holy Cross",'191',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "USC Upstate",'192',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Florida State",'193',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Maryland",'194',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Xavier",'195',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Notre Dame",'196',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Rutgers",'197',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Liberty\nLI",'198',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Longwood",'199',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Coppin State",'200',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Utah\nUTA",'201',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "North Alabama\nUN",'202',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Purdue",'203',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Miami (OH)",'204',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Ohio",'205',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Southern Miss\nUS",'206',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Stetson\nSTET",'207',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Villanova",'208',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Alcorn State\nA",'209',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Tulsa\nTLS",'210',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Memphis\nMEM",'211',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "SIU-Edwardsville",'212',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Missouri State\nMOSU",'213',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Binghamton\nB",'214',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Canisius",'215',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Oakland",'216',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "St Francis (BKN)",'217',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Weber State",'218',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Florida\nFL",'219',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Arkansas",'220',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Hartford",'221',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Wisconsin",'222',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Saint Joseph's",'223',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Presbyterian",'224',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Loyola Marymount\nLMU",'225',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Merrimack",'226',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Rhode Island\nU",'227',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Cleveland State\nC",'228',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Vanderbilt",'229',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Mississippi State\nMSS",'230',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Massachusetts",'231',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "West Virginia\nWVU",'232',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Rider",'233',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Charleston So",'234',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Arizona State\nASU",'235',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "George Mason\nGMU",'236',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Radford",'237',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UCLA\nUCLA",'238',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "SE Missouri State",'239',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Lehigh",'240',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Stanford\nSTA",'241',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Texas Tech\nTTU",'242',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Lafayette",'243',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "East Carolina\nECU",'244',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "FGCU\nFGCU",'245',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Norfolk State",'246',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Wake Forest",'247',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Houston Baptist",'248',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Western Illinois\nWI",'249',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UAB\nUAB",'250',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Oklahoma",'251',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Fresno State",'252',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "High Point",'253',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Grand Canyon\nGC",'254',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "CS Fullerton\nCS",'255',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Miami (FL)",'256',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "American",'257',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Northern Illinois",'258',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UT-Rio GV\nU",'259',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Ball State",'260',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "St Bonaventure",'261',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Duquesne\nDU",'262',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Georgia Tech",'263',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Southern U\nSOU",'264',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Montana State",'265',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "N Carolina Cent",'266',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Prairie View A&M\nP",'267',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Army", '268',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Tennessee Tech",'269',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Indiana State\nIN",'270',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Connecticut\nC",'271',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Hawaii",'272',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Texas Southern",'273',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Pittsburgh",'274',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Old Dominion\nODU",'275',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Texas A&M-",'276',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "New Hampshire\nU",'277',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Southern Utah",'278',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Fair Dickinson\nFDU",'279',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Davidson\nDAV",'280',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "North Carolina",'281',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "G Washington",'282',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Cent Conn St\nCCSU",'283',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Tulane\nTU",'284',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Wyoming",'285',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Illinois State\nI",'286',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "SE Louisiana",'287',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "South Carolina\nS",'288',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Gardner-Webb",'289',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Southern Illinois\nSIU",'290',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "TCU\nTCU",'291',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Wagner",'292',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Northern Colorado",'293',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Jackson State",'294',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Monmouth",'295',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UCF\nUCF",'296',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "La Salle",'297',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Baylor",'298',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Clemson",'299',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Maine\nM",'300',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Eastern Michigan",'301',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Temple\nTEM",'302',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "NJIT\nNJIT",'303',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Montana",'304',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Boston College",'305',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Ole Miss\nMISS",'306',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Siena",'307',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Delaware State",'308',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Northwstern St",'309',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Mount St Mary's",'310',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Niagara",'311',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Charlotte\nCHA",'312',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Oklahoma State\nOKST",'313',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "South Carolina St",'314',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Missouri",'315',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Quinnipiac",'316',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Northwestern",'317',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Tennessee",'318',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "South Florida\nUSF",'319',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Texas\nT",'320',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Harvard",'321',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Incarnate Word",'322',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Kansas State\nKSU",'323',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Columbia",'324',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Idaho",'325',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Northern Arizona",'326',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UL Monroe",'327',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "California\nCAL",'328',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Navy",'329',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Cal Poly\nC",'330',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Fairfield",'331',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Western Michigan",'332',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Maryland E Shore",'333',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Idaho State",'334',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Penn",'335',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Alabama State\nA",'336',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Kennesaw State\nKENN",'337',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Fordham",'338',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Marist",'339',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Florida A&",'340',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Sacramento State",'341',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Alabama A&M\nAAMU",'342',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Texas A&",'343',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Saint Peter's",'344',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Miss Valley State\nMVSU",'345',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Brown",'346',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Manhattan",'347',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Princeton",'348',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Virginia",'349',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Dartmouth",'350',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Iona",'351',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "Cornell",'352',table.TeamID)
    table['TeamID'] = np.where(table.STA20_Team == "UAPB\nARPB",'353',table.TeamID)

# %%
#########
#2020KenPom
#########

KenPom20['TeamID'] = ''
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Gonzaga",'1',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "South Dakota St.",'2',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Wright St.",'3',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Green Bay",'4',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "New Mexico",'5',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "BYU",'6',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Utah St.",'7',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Furman",'8',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Santa Clara",'9',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Winthrop",'10',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Florida",'11',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "South Dakota",'12',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Belmont",'13',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "FIU",'14',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "San Francisco",'15',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Sam Houston St.",'16',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Portland St.",'17',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Saint Mary's",'18',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Hofstra",'19',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Buffalo",'20',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Dakota",'21',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Colorado St.",'22',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Samford",'23',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Georgia St.",'24',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Coastal Carolina",'25',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Dayton",'26',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Duke",'27',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "LIU Brooklyn",'28',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cal St. Northridge",'29',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UTSA",'30',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Austin Peay",'31',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Pacific",'32',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Marquette",'33',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Kent St.",'34',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Georgetown",'35',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Boise St.",'36',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Stephen F. Austin",'37',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Creighton",'38',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Seattle",'39',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "William & Mary",'40',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northern Kentucky",'41',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Delaware",'42',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cal Baptist",'43',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "East Tennessee St.",'44',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Pepperdine",'45',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Nebraska Omaha",'46',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Oregon",'47',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Nicholls St.",'48',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "McNeese St.",'49',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Iowa",'50',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "VMI",'51',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UMass Lowell",'52',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Georgia Southern",'53',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Morgan St.",'54',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Rice",'55',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Tennessee St.",'56',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Oral Roberts",'57',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UNLV",'58',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "St. John's",'59',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Air Force",'60',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "South Alabama",'61',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Texas",'62',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Sacred Heart",'63',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Colgate",'64',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Alabama",'65',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "San Diego St.",'66',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Stony Brook",'67',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Central Michigan",'68',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Nevada",'69',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Youngstown St.",'70',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Hampton",'71',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Murray St.",'72',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Marshall",'73',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Eastern Kentucky",'74',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Arkansas St.",'75',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Valparaiso",'76',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Penn St.",'77',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Michigan St.",'78',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UNC Greensboro",'79',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "St. Francis PA",'80',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Arizona",'81',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Toledo",'82',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Troy",'83',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Milwaukee",'84',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UC Irvine",'85',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Little Rock",'86',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UNC Wilmington",'87',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northeastern",'88',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Jacksonville St.",'89',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Bradley",'90',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Purdue Fort Wayne",'91',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northern Iowa",'92',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Western Carolina",'93',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "The Citadel",'94',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Mercer",'95',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Dakota St.",'96',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Eastern Illinois",'97',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Western Kentucky",'98',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Texas St.",'99',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Drexel",'100',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Utah Valley",'101',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Detroit",'102',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Wofford",'103',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "N.C. State",'104',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "New Orleans",'105',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Richmond",'106',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Illinois",'107',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Florida Atlantic",'108',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "LSU",'109',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Loyola MD",'110',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Chattanooga",'111',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Middle Tennessee",'112',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "IUPUI",'113',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UC Davis",'114',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Louisiana Tech",'115',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Oregon St.",'116',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Seton Hall",'117',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Washington St.",'118',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "New Mexico St.",'119',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Portland",'120',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cal St. Bakersfield",'121',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Bowling Green",'122',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UT Arlington",'123',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Long Beach St.",'124',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Providence",'125',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "DePaul",'126',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Elon",'127',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Lamar",'128',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Auburn",'129',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Houston",'130',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Central Arkansas",'131',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Indiana",'132',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Bethune Cookman",'133',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Louisville",'134',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Boston University",'135',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Charleston",'136',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Drake",'137',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Eastern Washington",'138',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Lipscomb",'139',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "San Diego",'140',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Denver",'141',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Illinois Chicago",'142',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Washington",'143',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UNC Asheville",'144',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Towson",'145',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "James Madison",'146',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Chicago St.",'147',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Wichita St.",'148',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UMKC",'149',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Louisiana",'150',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Campbell",'151',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "USC",'152',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Grambling St.",'153',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UC Riverside",'154',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Syracuse",'155',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Georgia",'156',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Loyola Chicago",'157',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Morehead St.",'158',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Akron",'159',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Michigan",'160',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Evansville",'161',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UMBC",'162',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Ohio St.",'163',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Albany",'164',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Robert Morris",'165',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cincinnati",'166',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Butler",'167',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Vermont",'168',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Kansas",'169',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "SMU",'170',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Tennessee Martin",'171',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UTEP",'172',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Abilene Christian",'173',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "San Jose St.",'174',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Howard",'175',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Nebraska",'176',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Jacksonville",'177',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Carolina A&T",'178',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Bryant",'179',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Iowa St.",'180',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Minnesota 10",'181',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Virginia Tech",'182',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UC Santa Barbara",'183',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Colorado",'184',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Bucknell",'185',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Saint Louis",'186',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "VCU",'187',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Appalachian St.",'188',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Yale",'189',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Kentucky",'190',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Holy Cross",'191',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "USC Upstate",'192',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Florida St.",'193',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Maryland",'194',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Xavier",'195',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Notre Dame",'196',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Rutgers",'197',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Liberty",'198',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Longwood",'199',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Coppin St.",'200',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Utah",'201',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Alabama",'202',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Purdue",'203',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Miami OH",'204',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Ohio",'205',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Southern Miss",'206',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Stetson",'207',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Villanova",'208',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Alcorn St.",'209',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Tulsa",'210',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Memphis",'211',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "SIU Edwardsville",'212',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Missouri St.",'213',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Binghamton",'214',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Canisius",'215',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Oakland",'216',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "St. Francis NY",'217',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Weber St.",'218',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Florida 10",'219',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Arkansas",'220',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Hartford",'221',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Wisconsin",'222',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Saint Joseph's",'223',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Presbyterian",'224',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Loyola Marymount",'225',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Merrimack",'226',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Rhode Island",'227',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cleveland St.",'228',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Vanderbilt",'229',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Mississippi St.",'230',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Massachusetts",'231',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "West Virginia",'232',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Rider",'233',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Charleston Southern",'234',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Arizona St.",'235',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "George Mason",'236',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Radford",'237',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UCLA",'238',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Southeast Missouri St.",'239',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Lehigh",'240',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Stanford",'241',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Texas Tech",'242',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Lafayette",'243',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "East Carolina",'244',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Florida Gulf Coast",'245',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Norfolk St.",'246',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Wake Forest",'247',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Houston Baptist",'248',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Western Illinois",'249',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UAB",'250',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Oklahoma",'251',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Fresno St.",'252',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "High Point",'253',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Grand Canyon",'254',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cal St. Fullerton",'255',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Miami FL",'256',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "American",'257',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northern Illinois",'258',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UT Rio Grande Valley",'259',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Ball St.",'260',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "St. Bonaventure",'261',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Duquesne",'262',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Georgia Tech",'263',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Southern",'264',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Montana St.",'265',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Carolina Central",'266',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Prairie View A&M",'267',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Army", '268',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Tennessee Tech",'269',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Indiana St.",'270',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Connecticut",'271',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Hawaii",'272',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Texas Southern",'273',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Pittsburgh",'274',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Old Dominion",'275',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Texas A&M Corpus Chris",'276',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "New Hampshire",'277',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Southern Utah",'278',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Fairleigh Dickinson",'279',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Davidson",'280',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "North Carolina",'281',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "George Washington",'282',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Central Connecticut",'283',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Tulane",'284',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Wyoming",'285',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Illinois St.",'286',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Southeastern Louisiana",'287',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "South Carolina",'288',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Gardner Webb",'289',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Southern Illinois",'290',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "TCU",'291',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Wagner",'292',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northern Colorado",'293',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Jackson St.",'294',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Monmouth",'295',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "UCF",'296',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "La Salle",'297',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Baylor",'298',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Clemson",'299',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Maine",'300',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Eastern Michigan",'301',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Temple",'302',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "NJIT",'303',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Montana",'304',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Boston College",'305',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Mississippi",'306',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Siena",'307',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Delaware St.",'308',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northwestern St.",'309',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Mount St. Mary's",'310',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Niagara",'311',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Charlotte",'312',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Oklahoma St.",'313',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "South Carolina St.",'314',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Missouri",'315',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Quinnipiac",'316',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northwestern",'317',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Tennessee",'318',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "South Florida",'319',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Texas",'320',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Harvard",'321',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Incarnate Word",'322',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Kansas St.",'323',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Columbia",'324',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Idaho",'325',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Northern Arizona",'326',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Louisiana Monroe",'327',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "California",'328',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Navy",'329',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cal Poly",'330',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Fairfield",'331',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Western Michigan",'332',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Maryland Eastern Shore",'333',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Idaho St.",'334',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Penn",'335',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Alabama St.",'336',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Kennesaw St.",'337',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Fordham",'338',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Marist",'339',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Florida A&M",'340',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Sacramento St.",'341',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Alabama A&M",'342',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Texas A&M",'343',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Saint Peter's",'344',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Mississippi Valley St.",'345',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Brown",'346',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Manhattan",'347',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Princeton",'348',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Virginia",'349',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Dartmouth",'350',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Iona",'351',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Cornell",'352',KenPom20.TeamID)
KenPom20['TeamID'] = np.where(KenPom20.KP20_Team == "Arkansas Pine Bluff",'353',KenPom20.TeamID)

# %% [markdown]
# ## Give Stupid North Texas Their TeamID

# %%
ConferenceUSA20.at[0,'TeamID'] = 62

# %% [markdown]
# ## Save As CSV (HOME)

# %%
#########
#2020APPoll
#########

APPoll20.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020APPoll.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
#########
#2020TeamStats
#########

TeamStats20.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020TeamStats.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
#########
#2020KenPom
#########

KenPom20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020KenPom.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
#########
#2020PreSeasonAPPoll
#########

PSAPPoll20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020PreSeasonAPPoll.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
#########
#2020Standings
#########

AmericaEast20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\America East.csv", index = False, sep = ',', encoding = 'utf-8')
AmericanAthletic20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\American Athletic.csv", index = False, sep = ',', encoding = 'utf-8')
Atlantic1020.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic 10.csv", index = False, sep = ',', encoding = 'utf-8')
AtlanticCoast20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic Coast.csv", index = False, sep = ',', encoding = 'utf-8')
AtlanticSun20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic Sun.csv", index = False, sep = ',', encoding = 'utf-8')
Big1220.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big 12.csv", index = False, sep = ',', encoding = 'utf-8')
BigEast20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big East.csv", index = False, sep = ',', encoding = 'utf-8')
BigSky20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big Sky.csv", index = False, sep = ',', encoding = 'utf-8')
BigSouth20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big South.csv", index = False, sep = ',', encoding = 'utf-8')
BigTen20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big Ten.csv", index = False, sep = ',', encoding = 'utf-8')
BigWest20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big West.csv", index = False, sep = ',', encoding = 'utf-8')
Colonial20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Colonial.csv", index = False, sep = ',', encoding = 'utf-8')
ConferenceUSA20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Conference USA.csv", index = False, sep = ',', encoding = 'utf-8')
Horizon20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Horizon.csv", index = False, sep = ',', encoding = 'utf-8')
Ivy20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Ivy.csv", index = False, sep = ',', encoding = 'utf-8')
MetroAtlanticAthletic20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Metro Atlantic Athletic.csv", index = False, sep = ',', encoding = 'utf-8')
MidEasternAthletic20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mid Eastern Athletic.csv", index = False, sep = ',', encoding = 'utf-8')
MidAmerican20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mid-American.csv", index = False, sep = ',', encoding = 'utf-8')
MissouriValley20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Missouri Valley.csv", index = False, sep = ',', encoding = 'utf-8')
MountainWest20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mountain West.csv", index = False, sep = ',', encoding = 'utf-8')
Northeast20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Northeast.csv", index = False, sep = ',', encoding = 'utf-8')
OhioValley20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Ohio Valley.csv", index = False, sep = ',', encoding = 'utf-8')
Pacific1220.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Pacific 12.csv", index = False, sep = ',', encoding = 'utf-8')
PatriotLeague20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Patriot League.csv", index = False, sep = ',', encoding = 'utf-8')
Southeastern20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southeastern.csv", index = False, sep = ',', encoding = 'utf-8')
Southern20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southern.csv", index = False, sep = ',', encoding = 'utf-8')
Southland20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southland.csv", index = False, sep = ',', encoding = 'utf-8')
SouthwesternAthletic20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southwestern Athletic.csv", index = False, sep = ',', encoding = 'utf-8')
SummitLeague20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Summit League.csv", index = False, sep = ',', encoding = 'utf-8')
SunBelt20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Sun Belt.csv", index = False, sep = ',', encoding = 'utf-8')
WestCoast20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\West Coast.csv", index = False, sep = ',', encoding = 'utf-8')
WesternAthletic20.to_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Western Athletic.csv", index = False, sep = ',', encoding = 'utf-8')

# %% [markdown]
# ## Read CSV's (HOME)

# %%
##########
#2020TeamStats
##########

TeamStats20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020TeamStats.csv")

# %%
##########
#2020APPoll
##########

APPoll20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020APPoll.csv")

# %%
##########
#2020KenPom
##########

KenPom20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020KenPom.csv")

# %%
##########
#2020PreSeasonAPPoll
##########

PSAPPoll20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020PreSeasonAPPoll.csv")

# %%
##########
#2020Standings
##########

AmericaEast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\America East.csv")
AmericanAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\American Athletic.csv")
Atlantic1020 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic 10.csv")
AtlanticCoast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic Coast.csv")
AtlanticSun20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Atlantic Sun.csv")
Big1220 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big 12.csv")
BigEast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big East.csv")
BigSky20  = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big Sky.csv")
BigSouth20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big South.csv")
BigTen20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big Ten.csv")
BigWest20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Big West.csv")
Colonial20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Colonial.csv")
ConferenceUSA20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Conference USA.csv")
Horizon20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Horizon.csv")
Ivy20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Ivy.csv")
MetroAtlanticAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Metro Atlantic Athletic.csv")
MidEasternAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mid Eastern Athletic.csv")
MidAmerican20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mid-American.csv")
MissouriValley20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Missouri Valley.csv")
MountainWest20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Mountain West.csv")
Northeast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Northeast.csv")
OhioValley20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Ohio Valley.csv")
Pacific1220 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Pacific 12.csv")
PatriotLeague20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Patriot League.csv")
Southeastern20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southeastern.csv")
Southern20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southern.csv")
Southland20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southland.csv")
SouthwesternAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Southwestern Athletic.csv")
SummitLeague20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Summit League.csv")
SunBelt20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Sun Belt.csv")
WestCoast20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\West Coast.csv")
WesternAthletic20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Leagues\\Western Athletic.csv")
Tables20 = [AmericaEast20, AmericanAthletic20, Atlantic1020, AtlanticCoast20, AtlanticSun20, Big1220, BigEast20, BigSky20, BigSouth20, BigTen20, BigWest20, Colonial20, ConferenceUSA20, Horizon20, Ivy20, MetroAtlanticAthletic20, MidEasternAthletic20, MidAmerican20, MissouriValley20, MountainWest20, Northeast20, OhioValley20, Pacific1220, PatriotLeague20, Southeastern20, Southern20, Southland20, SouthwesternAthletic20, SummitLeague20, SunBelt20, WestCoast20, WesternAthletic20]

# %% [markdown]
# ## Merge Datasets

# %%
##########
#2020FullDataset
##########

df1_20 = TeamStats20.merge(AmericaEast20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df2_20 = TeamStats20.merge(AmericanAthletic20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df3_20 = TeamStats20.merge(Atlantic1020, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df4_20 = TeamStats20.merge(AtlanticCoast20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df5_20 = TeamStats20.merge(AtlanticSun20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df6_20 = TeamStats20.merge(Big1220, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df7_20 = TeamStats20.merge(BigEast20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df8_20 = TeamStats20.merge(BigSky20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df9_20 = TeamStats20.merge(BigSouth20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df10_20 = TeamStats20.merge(BigTen20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df11_20 = TeamStats20.merge(BigWest20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df12_20 = TeamStats20.merge(Colonial20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df13_20 = TeamStats20.merge(ConferenceUSA20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df14_20 = TeamStats20.merge(Horizon20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df15_20 = TeamStats20.merge(Ivy20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df16_20 = TeamStats20.merge(MetroAtlanticAthletic20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df17_20 = TeamStats20.merge(MidEasternAthletic20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df18_20 = TeamStats20.merge(MidAmerican20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df19_20 = TeamStats20.merge(MissouriValley20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df20_20 = TeamStats20.merge(MountainWest20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df21_20 = TeamStats20.merge(Northeast20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df22_20 = TeamStats20.merge(OhioValley20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df23_20 = TeamStats20.merge(Pacific1220, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df24_20 = TeamStats20.merge(PatriotLeague20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df25_20 = TeamStats20.merge(Southeastern20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df26_20 = TeamStats20.merge(Southern20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df27_20 = TeamStats20.merge(Southland20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df28_20 = TeamStats20.merge(SouthwesternAthletic20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df29_20 = TeamStats20.merge(SummitLeague20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df30_20 = TeamStats20.merge(SunBelt20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df31_20 = TeamStats20.merge(WestCoast20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))
df32_20 = TeamStats20.merge(WesternAthletic20, left_on='TeamID', right_on='TeamID', suffixes=('','_2'))

# %%
##########
#2020FullDataset
##########

df20 = df1_20.append([df2_20, df3_20, df4_20, df5_20, df6_20, df7_20, df8_20, df9_20, df10_20, df11_20, df12_20, df13_20, df14_20, df15_20, df16_20, df17_20, df18_20, df19_20, df20_20, df21_20, df22_20, df23_20, df24_20, df25_20, df26_20, df27_20, df28_20, df29_20, df30_20, df31_20, df32_20], ignore_index=True)
df20 = df20.merge(APPoll20,how='left', left_on='TeamID', right_on='TeamID')
df20 = df20.merge(KenPom20, how='left', left_on='TeamID', right_on='TeamID')
df20 = df20.merge(PSAPPoll20, how = 'left', left_on = 'TeamID', right_on = 'TeamID')

# %% [markdown]
# ## Drop Columns

# %%
##########
#2020FullDataset
##########

df20 = df20.drop('STA20_Team', axis = 1).drop('AP20_Team', axis = 1).drop('AP20_W', axis = 1).drop('AP20_L', axis = 1).drop('KP20_Team', axis = 1).drop('KP20_W', axis = 1).drop('KP20_L', axis = 1).drop('PS20_Team', axis = 1).drop('TS20_PTS', axis = 1)

# %% [markdown]
# ## Reorder Columns

# %%
##########
#2020FullDataset
##########

df20 = df20[['AP20_Rnk', 'PS20_Rnk', 'KP20_Rank', 'TeamID', 'TS20_Team', 'KP20_Conference', 'TS20_GP', 'STA20_W', 'STA20_L', 'STA20_Pct', 'STA20_Strk', 'STA20_Conf_W', 'STA20_Conf_L', 'STA20_Conf_Pct', 'STA20_Home_W', 'STA20_Home_L', 'STA20_Away_W', 'STA20_Away_L', 'STA20_Neutral_W', 'STA20_Neutral_L', 'STA20_Top25_W', 'STA20_Top25_L', 'STA20_Conf_PF', 'STA20_Conf_PA', 'STA20_Conf_PPG', 'STA20_Conf_PAPG', 'STA20_PF', 'STA20_PA', 'STA20_PPG', 'STA20_PAPG', 'TS20_FGM', 'TS20_FGA', 'TS20_FG%', 'TS20_3PM', 'TS20_3PA', 'TS20_3P%', 'TS20_FTM', 'TS20_FTA', 'TS20_FT%', 'KP20_Ajusted Efficiency Margin', 'KP20_Adjusted Offensive Efficiency', 'KP20_AOE Rk', 'KP20_Adjusted Defensive Efficiency', 'KP20_ADE Rk', 'KP20_Adjusted Tempo', 'KP20_AT Rk', 'KP20_Luck', 'KP20_Luck Rk', 'KP20_Strength of Schedule', 'KP20_SOS Rk', 'KP20_Non-Conference Strength of Schedule', 'KP20_NCSOS Rk', 'KP20_Average Opponents Offensive Efficiency', 'KP20_AOOE Rk', 'KP20_Average Opponents Defensive Efficiency', 'KP20_AODE Rk']]

# %% [markdown]
# ## Save As CSV (HOME)

# %%
##########
#2020FullDataset
##########

df20.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020FullDataset.csv", index = False, sep = ',', encoding = 'utf-8')

# %% [markdown]
# ## Read CSV's (HOME)

# %%
##########
#2020FullDataset
##########

FDS20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020FullDataset.csv")

# %%
##########
#2020Tournament
##########

NCAA20 = pd.read_csv("C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Tournament.csv")

# %% [markdown]
# ## Merge DataFrames

# %%
Final20 = FDS20.merge(NCAA20,how='left', left_on='TeamID', right_on='TeamID')

# %% [markdown]
# ## Drop Teams That Weren't In The Tournament

# %%
Final20 = Final20[Final20['Seed'].notna()]

# %% [markdown]
# ## Save As CSV

# %%
##########
#2020Final
##########

Final20.to_csv(r"C:\\Users\\Acer\\Desktop\\Web Scraping\\2020Final.csv", index = False, sep = ',', encoding = 'utf-8')

# %%
Final20
# Out:
#      AP20_Rnk  PS20_Rnk  KP20_Rank  TeamID      TS20_Team KP20_Conference  \
# 1         NaN       NaN       76.0     168        Vermont              AE
# 10       22.0      22.0       14.0     130        Houston            Amer
# 12        NaN       NaN       39.0     148  Wichita State            Amer
# 14        NaN       NaN       44.0     166     Cincinnati            Amer
# 21        3.0       3.0        4.0      26         Dayton             A10
# ..        ...       ...        ...     ...            ...             ...
# 326       NaN       NaN      129.0      86    Little Rock              SB
# 333       2.0       2.0        2.0       1        Gonzaga             WCC
# 334       NaN       NaN       38.0      18   Saint Mary's             WCC
# 335      18.0      18.0       13.0       6            BYU             WCC
# 340       NaN       NaN      286.0     120       Portland             WCC
#
#      TS20_GP  STA20_W  STA20_L  STA20_Pct  ... KP20_Strength of Schedule  \
# ...
